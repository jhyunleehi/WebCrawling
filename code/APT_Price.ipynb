# %%
import requests

# %%
url = 'http://openapi.molit.go.kr:8081/'
path = 'OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/'
oper = 'getRTMSDataSvcAptTrade'

# %%
url + path + oper
# Out:
# 'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTrade'

# %%
apiKey = ''

# %%
query = {
    'LAWD_CD': '11680', 
    'DEAL_YMD': '202401', 
    'serviceKey': apiKey
}

# %%
res = requests.get(url = url + path + oper, params = query)

# %%
res.status_code
# Out:
# 200

# %%
res.headers['content-type']
# Out:
# 'application/xml'

# %%
import xmltodict

# %%
dat = xmltodict.parse(res.text)

# %%
from pprint import pprint

# %%
pprint(dat)
# Out:
# {'response': {'body': {'items': {'item': [{'거래금액': '289,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2006',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': "역삼I'PARK",
#                                            '월': '1',
#                                            '일': '4',
#                                            '전용면적': '116.285',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '713-11',
#                                            '지역코드': '11680',
#                                            '층': '14',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '70,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2002',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': '역삼동하나빌',
#                                            '월': '1',
#                                            '일': '5',
#                                            '전용면적': '50.89',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '681-26',
#                                            '지역코드': '11680',
#                                            '층': '9',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '295,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2006',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': "역삼I'PARK",
#                                            '월': '1',
#                                            '일': '5',
#                                            '전용면적': '116.285',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '713-11',
#                                            '지역코드': '11680',
#                                            '층': '15',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '215,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2009',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': '래미안그레이튼',
#                                            '월': '1',
#                                            '일': '6',
#                                            '전용면적': '70.98',
#                                            '중개사소재지': '서울 강남구, 서울 송파구',
#                                            '지번': '763-16',
#                                            '지역코드': '11680',
#                                            '층': '12',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '65,000',
#                                            '거래유형': '직거래',
#                                            '건축년도': '2003',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': '24.01.19',
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': '노블스위트',
#                                            '월': '1',
#                                            '일': '6',
#                                            '전용면적': '84.85',
#                                            '중개사소재지': None,
#                                            '지번': '747',
#                                            '지역코드': '11680',
#                                            '층': '5',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '30,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2002',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': '24.02.05',
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': '대우디오빌',
#                                            '월': '1',
#                                            '일': '8',
#                                            '전용면적': '30.03',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '720-25',
#                                            '지역코드': '11680',
#                                            '층': '9',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '235,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2006',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': '역삼푸르지오',
#                                            '월': '1',
#                                            '일': '9',
#                                            '전용면적': '84.9097',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '754-1',
#                                            '지역코드': '11680',
#                                            '층': '8',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '188,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2010',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': '래미안그레이튼(진달래2차)',
#                                            '월': '1',
#                                            '일': '9',
#                                            '전용면적': '59.78',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '762-3',
#                                            '지역코드': '11680',
#                                            '층': '19',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '320,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2014',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': '테헤란아이파크',
#                                            '월': '1',
#                                            '일': '10',
#                                            '전용면적': '118.0315',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '709-5',
#                                            '지역코드': '11680',
#                                            '층': '11',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '31,300',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2002',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': '대우디오빌',
#                                            '월': '1',
#                                            '일': '12',
#                                            '전용면적': '30.03',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '720-25',
#                                            '지역코드': '11680',
#                                            '층': '17',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '322,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2001',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': '현대까르띠에710',
#                                            '월': '1',
#                                            '일': '12',
#                                            '전용면적': '149.7',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '710',
#                                            '지역코드': '11680',
#                                            '층': '21',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '21,700',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2003',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': '진넥스빌2',
#                                            '월': '1',
#                                            '일': '13',
#                                            '전용면적': '23.85',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '706-24',
#                                            '지역코드': '11680',
#                                            '층': '11',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '233,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2016',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': '역삼자이',
#                                            '월': '1',
#                                            '일': '13',
#                                            '전용면적': '84.993',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '711-3',
#                                            '지역코드': '11680',
#                                            '층': '9',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '243,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2014',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': '테헤란아이파크',
#                                            '월': '1',
#                                            '일': '15',
#                                            '전용면적': '92.6232',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '709-5',
#                                            '지역코드': '11680',
#                                            '층': '13',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '17,400',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2012',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': '대명벨리온',
#                                            '월': '1',
#                                            '일': '16',
#                                            '전용면적': '17.684',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '727-2',
#                                            '지역코드': '11680',
#                                            '층': '5',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '17,200',
#                                            '거래유형': '직거래',
#                                            '건축년도': '2012',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': '24.01.22',
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '역삼동',
#                                            '아파트': '대명벨리온',
#                                            '월': '1',
#                                            '일': '22',
#                                            '전용면적': '17.684',
#                                            '중개사소재지': None,
#                                            '지번': '727-2',
#                                            '지역코드': '11680',
#                                            '층': '3',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '197,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2005',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '법정동': '역삼동',
#                                            '아파트': 'e-편한세상',
#                                            '월': '1',
#                                            '일': '27',
#                                            '전용면적': '59.947',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '755-4',
#                                            '지역코드': '11680',
#                                            '층': '13',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '263,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2006',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '법정동': '역삼동',
#                                            '아파트': '개나리푸르지오',
#                                            '월': '1',
#                                            '일': '30',
#                                            '전용면적': '84.6815',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '755-1',
#                                            '지역코드': '11680',
#                                            '층': '9',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '223,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2021',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '개포동',
#                                            '아파트': '개포더샵트리에',
#                                            '월': '1',
#                                            '일': '3',
#                                            '전용면적': '108.0923',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '651-1',
#                                            '지역코드': '11680',
#                                            '층': '14',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '217,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2019',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '개포동',
#                                            '아파트': '디에이치아너힐즈',
#                                            '월': '1',
#                                            '일': '9',
#                                            '전용면적': '59.8072',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '138',
#                                            '지역코드': '11680',
#                                            '층': '20',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '187,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2020',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '개포동',
#                                            '아파트': '개포래미안포레스트',
#                                            '월': '1',
#                                            '일': '9',
#                                            '전용면적': '59.96',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '1282',
#                                            '지역코드': '11680',
#                                            '층': '29',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '212,500',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2019',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '개포동',
#                                            '아파트': '디에이치아너힐즈',
#                                            '월': '1',
#                                            '일': '10',
#                                            '전용면적': '59.7479',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '138',
#                                            '지역코드': '11680',
#                                            '층': '26',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '130,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1992',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '개포동',
#                                            '아파트': '삼익대청아파트',
#                                            '월': '1',
#                                            '일': '11',
#                                            '전용면적': '51.12',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '12',
#                                            '지역코드': '11680',
#                                            '층': '12',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '216,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2023',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '개포동',
#                                            '아파트': '개포자이프레지던스',
#                                            '월': '1',
#                                            '일': '12',
#                                            '전용면적': '59.98',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '189',
#                                            '지역코드': '11680',
#                                            '층': '26',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '113,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1992',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '개포동',
#                                            '아파트': '성원대치2단지아파트',
#                                            '월': '1',
#                                            '일': '13',
#                                            '전용면적': '39.53',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '12',
#                                            '지역코드': '11680',
#                                            '층': '11',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '215,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1983',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '개포동',
#                                            '아파트': '개포주공5단지',
#                                            '월': '1',
#                                            '일': '13',
#                                            '전용면적': '53.98',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '187',
#                                            '지역코드': '11680',
#                                            '층': '8',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '161,000',
#                                            '거래유형': '직거래',
#                                            '건축년도': '2019',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '법인',
#                                            '매수자': '개인',
#                                            '법정동': '개포동',
#                                            '아파트': '래미안블레스티지',
#                                            '월': '1',
#                                            '일': '15',
#                                            '전용면적': '49.909',
#                                            '중개사소재지': None,
#                                            '지번': '1280',
#                                            '지역코드': '11680',
#                                            '층': '12',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '116,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1991',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '법정동': '개포동',
#                                            '아파트': 'SH대치1단지아파트',
#                                            '월': '1',
#                                            '일': '17',
#                                            '전용면적': '25.35',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '12',
#                                            '지역코드': '11680',
#                                            '층': '8',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '209,500',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2019',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '법정동': '개포동',
#                                            '아파트': '디에이치아너힐즈',
#                                            '월': '1',
#                                            '일': '18',
#                                            '전용면적': '59.8732',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '138',
#                                            '지역코드': '11680',
#                                            '층': '16',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '340,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1984',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '개포동',
#                                            '아파트': '경남2차',
#                                            '월': '1',
#                                            '일': '25',
#                                            '전용면적': '182.2',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '649',
#                                            '지역코드': '11680',
#                                            '층': '10',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '187,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2011',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '청담동',
#                                            '아파트': '청담자이',
#                                            '월': '1',
#                                            '일': '2',
#                                            '전용면적': '49.619',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '134-38',
#                                            '지역코드': '11680',
#                                            '층': '8',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '217,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1984',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '청담동',
#                                            '아파트': '진흥아파트',
#                                            '월': '1',
#                                            '일': '5',
#                                            '전용면적': '109.31',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '65',
#                                            '지역코드': '11680',
#                                            '층': '1',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '350,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1999',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '청담동',
#                                            '아파트': '청담현대3차아파트',
#                                            '월': '1',
#                                            '일': '9',
#                                            '전용면적': '109.53',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '127-31',
#                                            '지역코드': '11680',
#                                            '층': '17',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '163,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1988',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '청담동',
#                                            '아파트': '현대아파트',
#                                            '월': '1',
#                                            '일': '11',
#                                            '전용면적': '84.92',
#                                            '중개사소재지': '서울 강남구, 서울 강동구',
#                                            '지번': '23',
#                                            '지역코드': '11680',
#                                            '층': '4',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '175,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2011',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '청담동',
#                                            '아파트': '청담자이',
#                                            '월': '1',
#                                            '일': '17',
#                                            '전용면적': '49.639',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '134-38',
#                                            '지역코드': '11680',
#                                            '층': '5',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '165,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1988',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '청담동',
#                                            '아파트': '현대아파트',
#                                            '월': '1',
#                                            '일': '19',
#                                            '전용면적': '84.92',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '23',
#                                            '지역코드': '11680',
#                                            '층': '3',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '200,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2011',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '청담동',
#                                            '아파트': '청담자이',
#                                            '월': '1',
#                                            '일': '31',
#                                            '전용면적': '49.593',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '134-38',
#                                            '지역코드': '11680',
#                                            '층': '18',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '425,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2007',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '삼성동',
#                                            '아파트': '롯데캐슬프레미어',
#                                            '월': '1',
#                                            '일': '2',
#                                            '전용면적': '213.435',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '11',
#                                            '지역코드': '11680',
#                                            '층': '8',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '150,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2004',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '삼성동',
#                                            '아파트': '삼성동대성유니드',
#                                            '월': '1',
#                                            '일': '3',
#                                            '전용면적': '78.69',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '129',
#                                            '지역코드': '11680',
#                                            '층': '6',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '43,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2003',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '삼성동',
#                                            '아파트': 'LG선릉에클라트(A)',
#                                            '월': '1',
#                                            '일': '4',
#                                            '전용면적': '36.16',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '142-7',
#                                            '지역코드': '11680',
#                                            '층': '4',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '900,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2004',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '삼성동',
#                                            '아파트': '아이파크',
#                                            '월': '1',
#                                            '일': '9',
#                                            '전용면적': '175.052',
#                                            '중개사소재지': '서울 강남구, 서울 송파구',
#                                            '지번': '87',
#                                            '지역코드': '11680',
#                                            '층': '33',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '93,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2004',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '삼성동',
#                                            '아파트': '이안애2차',
#                                            '월': '1',
#                                            '일': '10',
#                                            '전용면적': '64.26',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '130-6',
#                                            '지역코드': '11680',
#                                            '층': '7',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '37,500',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2004',
#                                            '년': '2024',
#                                            '동': 'LG선릉에클라트B',
#                                            '등기일자': '24.02.01',
#                                            '매도자': '기타',
#                                            '매수자': '개인',
#                                            '법정동': '삼성동',
#                                            '아파트': 'LG선릉에클라트(B)',
#                                            '월': '1',
#                                            '일': '10',
#                                            '전용면적': '36.35',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '142-3',
#                                            '지역코드': '11680',
#                                            '층': '13',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '140,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1998',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '법정동': '삼성동',
#                                            '아파트': '삼성동한솔아파트',
#                                            '월': '1',
#                                            '일': '22',
#                                            '전용면적': '58.57',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '4-6',
#                                            '지역코드': '11680',
#                                            '층': '5',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '300,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2007',
#                                            '년': '2024',
#                                            '동': None,
# ...
#                                            '매수자': '개인',
#                                            '법정동': '도곡동',
#                                            '아파트': '포스코트',
#                                            '월': '1',
#                                            '일': '4',
#                                            '전용면적': '209.03',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '164-6',
#                                            '지역코드': '11680',
#                                            '층': '9',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '229,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1986',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '도곡동',
#                                            '아파트': '우성사원5',
#                                            '월': '1',
#                                            '일': '6',
#                                            '전용면적': '78.99',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '463-1',
#                                            '지역코드': '11680',
#                                            '층': '7',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '733,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2002',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '도곡동',
#                                            '아파트': '타워팰리스1',
#                                            '월': '1',
#                                            '일': '6',
#                                            '전용면적': '244.66',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '467',
#                                            '지역코드': '11680',
#                                            '층': '54',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '367,500',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1985',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '도곡동',
#                                            '아파트': '우성4',
#                                            '월': '1',
#                                            '일': '6',
#                                            '전용면적': '152.74',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '465',
#                                            '지역코드': '11680',
#                                            '층': '9',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '570,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2006',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '도곡동',
#                                            '아파트': '이니그마빌-III',
#                                            '월': '1',
#                                            '일': '10',
#                                            '전용면적': '240.55',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '201',
#                                            '지역코드': '11680',
#                                            '층': '7',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '225,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1985',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '도곡동',
#                                            '아파트': '한신(개포)',
#                                            '월': '1',
#                                            '일': '11',
#                                            '전용면적': '59.48',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '464',
#                                            '지역코드': '11680',
#                                            '층': '7',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '184,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2006',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '도곡동',
#                                            '아파트': '도곡렉슬',
#                                            '월': '1',
#                                            '일': '13',
#                                            '전용면적': '59.9772',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '527',
#                                            '지역코드': '11680',
#                                            '층': '16',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '100,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2005',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '도곡동',
#                                            '아파트': '도곡하이빌',
#                                            '월': '1',
#                                            '일': '14',
#                                            '전용면적': '119.33',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '919-3',
#                                            '지역코드': '11680',
#                                            '층': '4',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '497,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2002',
#                                            '년': '2024',
#                                            '동': '비',
#                                            '등기일자': '24.01.19',
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '도곡동',
#                                            '아파트': '타워팰리스1',
#                                            '월': '1',
#                                            '일': '15',
#                                            '전용면적': '222.48',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '467',
#                                            '지역코드': '11680',
#                                            '층': '64',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '400,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2004',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '도곡동',
#                                            '아파트': '타워팰리스3',
#                                            '월': '1',
#                                            '일': '17',
#                                            '전용면적': '163.567',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '467-29',
#                                            '지역코드': '11680',
#                                            '층': '34',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '282,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '2006',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '법정동': '도곡동',
#                                            '아파트': '도곡렉슬',
#                                            '월': '1',
#                                            '일': '19',
#                                            '전용면적': '84.9984',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '527',
#                                            '지역코드': '11680',
#                                            '층': '20',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '185,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1995',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '도곡동',
#                                            '아파트': '럭키(963)',
#                                            '월': '1',
#                                            '일': '20',
#                                            '전용면적': '84.97',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '963',
#                                            '지역코드': '11680',
#                                            '층': '4',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '181,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1994',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '도곡동',
#                                            '아파트': '삼성',
#                                            '월': '1',
#                                            '일': '23',
#                                            '전용면적': '73.41',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '161',
#                                            '지역코드': '11680',
#                                            '층': '12',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '48,000',
#                                            '거래유형': '중개거래',
#                                            '건축년도': '1999',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '매도자': '개인',
#                                            '매수자': '개인',
#                                            '법정동': '도곡동',
#                                            '아파트': '현대비젼21',
#                                            '월': '1',
#                                            '일': '27',
#                                            '전용면적': '34.995',
#                                            '중개사소재지': '서울 강남구',
#                                            '지번': '467-19',
#                                            '지역코드': '11680',
#                                            '층': '27',
#                                            '해제사유발생일': None,
#                                            '해제여부': None},
#                                           {'거래금액': '481,000',
#                                            '거래유형': '직거래',
#                                            '건축년도': '2002',
#                                            '년': '2024',
#                                            '동': None,
#                                            '등기일자': None,
#                                            '법정동': '도곡동',
#                                            '아파트': '타워팰리스1',
#                                            '월': '1',
#                                            '일': '29',
#                                            '전용면적': '164.97',
#                                            '중개사소재지': None,
#                                            '지번': '467',
#                                            '지역코드': '11680',
#                                            '층': '53',
#                                            '해제사유발생일': None,
#                                            '해제여부': None}]},
#                        'numOfRows': '10',
#                        'pageNo': '1',
#                        'totalCount': '124'},
#               'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'}}}

# %%
dat['response']['body']['items']['item']
# Out:
# [{'거래금액': '289,000',
#   '거래유형': '중개거래',
#   '건축년도': '2006',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': "역삼I'PARK",
#   '월': '1',
#   '일': '4',
#   '전용면적': '116.285',
#   '중개사소재지': '서울 강남구',
#   '지번': '713-11',
#   '지역코드': '11680',
#   '층': '14',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '70,000',
#   '거래유형': '중개거래',
#   '건축년도': '2002',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': '역삼동하나빌',
#   '월': '1',
#   '일': '5',
#   '전용면적': '50.89',
#   '중개사소재지': '서울 강남구',
#   '지번': '681-26',
#   '지역코드': '11680',
#   '층': '9',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '295,000',
#   '거래유형': '중개거래',
#   '건축년도': '2006',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': "역삼I'PARK",
#   '월': '1',
#   '일': '5',
#   '전용면적': '116.285',
#   '중개사소재지': '서울 강남구',
#   '지번': '713-11',
#   '지역코드': '11680',
#   '층': '15',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '215,000',
#   '거래유형': '중개거래',
#   '건축년도': '2009',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': '래미안그레이튼',
#   '월': '1',
#   '일': '6',
#   '전용면적': '70.98',
#   '중개사소재지': '서울 강남구, 서울 송파구',
#   '지번': '763-16',
#   '지역코드': '11680',
#   '층': '12',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '65,000',
#   '거래유형': '직거래',
#   '건축년도': '2003',
#   '년': '2024',
#   '동': None,
#   '등기일자': '24.01.19',
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': '노블스위트',
#   '월': '1',
#   '일': '6',
#   '전용면적': '84.85',
#   '중개사소재지': None,
#   '지번': '747',
#   '지역코드': '11680',
#   '층': '5',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '30,000',
#   '거래유형': '중개거래',
#   '건축년도': '2002',
#   '년': '2024',
#   '동': None,
#   '등기일자': '24.02.05',
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': '대우디오빌',
#   '월': '1',
#   '일': '8',
#   '전용면적': '30.03',
#   '중개사소재지': '서울 강남구',
#   '지번': '720-25',
#   '지역코드': '11680',
#   '층': '9',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '235,000',
#   '거래유형': '중개거래',
#   '건축년도': '2006',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': '역삼푸르지오',
#   '월': '1',
#   '일': '9',
#   '전용면적': '84.9097',
#   '중개사소재지': '서울 강남구',
#   '지번': '754-1',
#   '지역코드': '11680',
#   '층': '8',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '188,000',
#   '거래유형': '중개거래',
#   '건축년도': '2010',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': '래미안그레이튼(진달래2차)',
#   '월': '1',
#   '일': '9',
#   '전용면적': '59.78',
#   '중개사소재지': '서울 강남구',
#   '지번': '762-3',
#   '지역코드': '11680',
#   '층': '19',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '320,000',
#   '거래유형': '중개거래',
#   '건축년도': '2014',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': '테헤란아이파크',
#   '월': '1',
#   '일': '10',
#   '전용면적': '118.0315',
#   '중개사소재지': '서울 강남구',
#   '지번': '709-5',
#   '지역코드': '11680',
#   '층': '11',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '31,300',
#   '거래유형': '중개거래',
#   '건축년도': '2002',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': '대우디오빌',
#   '월': '1',
#   '일': '12',
#   '전용면적': '30.03',
#   '중개사소재지': '서울 강남구',
#   '지번': '720-25',
#   '지역코드': '11680',
#   '층': '17',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '322,000',
#   '거래유형': '중개거래',
#   '건축년도': '2001',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': '현대까르띠에710',
#   '월': '1',
#   '일': '12',
#   '전용면적': '149.7',
#   '중개사소재지': '서울 강남구',
#   '지번': '710',
#   '지역코드': '11680',
#   '층': '21',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '21,700',
#   '거래유형': '중개거래',
#   '건축년도': '2003',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': '진넥스빌2',
#   '월': '1',
#   '일': '13',
#   '전용면적': '23.85',
#   '중개사소재지': '서울 강남구',
#   '지번': '706-24',
#   '지역코드': '11680',
#   '층': '11',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '233,000',
#   '거래유형': '중개거래',
#   '건축년도': '2016',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': '역삼자이',
#   '월': '1',
#   '일': '13',
#   '전용면적': '84.993',
#   '중개사소재지': '서울 강남구',
#   '지번': '711-3',
#   '지역코드': '11680',
#   '층': '9',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '243,000',
#   '거래유형': '중개거래',
#   '건축년도': '2014',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': '테헤란아이파크',
#   '월': '1',
#   '일': '15',
#   '전용면적': '92.6232',
#   '중개사소재지': '서울 강남구',
#   '지번': '709-5',
#   '지역코드': '11680',
#   '층': '13',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '17,400',
#   '거래유형': '중개거래',
#   '건축년도': '2012',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': '대명벨리온',
#   '월': '1',
#   '일': '16',
#   '전용면적': '17.684',
#   '중개사소재지': '서울 강남구',
#   '지번': '727-2',
#   '지역코드': '11680',
#   '층': '5',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '17,200',
#   '거래유형': '직거래',
#   '건축년도': '2012',
#   '년': '2024',
#   '동': None,
#   '등기일자': '24.01.22',
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '역삼동',
#   '아파트': '대명벨리온',
#   '월': '1',
#   '일': '22',
#   '전용면적': '17.684',
#   '중개사소재지': None,
#   '지번': '727-2',
#   '지역코드': '11680',
#   '층': '3',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '197,000',
#   '거래유형': '중개거래',
#   '건축년도': '2005',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '법정동': '역삼동',
#   '아파트': 'e-편한세상',
#   '월': '1',
#   '일': '27',
#   '전용면적': '59.947',
#   '중개사소재지': '서울 강남구',
#   '지번': '755-4',
#   '지역코드': '11680',
#   '층': '13',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '263,000',
#   '거래유형': '중개거래',
#   '건축년도': '2006',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '법정동': '역삼동',
#   '아파트': '개나리푸르지오',
#   '월': '1',
#   '일': '30',
#   '전용면적': '84.6815',
#   '중개사소재지': '서울 강남구',
#   '지번': '755-1',
#   '지역코드': '11680',
#   '층': '9',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '223,000',
#   '거래유형': '중개거래',
#   '건축년도': '2021',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '개포동',
#   '아파트': '개포더샵트리에',
#   '월': '1',
#   '일': '3',
#   '전용면적': '108.0923',
#   '중개사소재지': '서울 강남구',
#   '지번': '651-1',
#   '지역코드': '11680',
#   '층': '14',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '217,000',
#   '거래유형': '중개거래',
#   '건축년도': '2019',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '개포동',
#   '아파트': '디에이치아너힐즈',
#   '월': '1',
#   '일': '9',
#   '전용면적': '59.8072',
#   '중개사소재지': '서울 강남구',
#   '지번': '138',
#   '지역코드': '11680',
#   '층': '20',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '187,000',
#   '거래유형': '중개거래',
#   '건축년도': '2020',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '개포동',
#   '아파트': '개포래미안포레스트',
#   '월': '1',
#   '일': '9',
#   '전용면적': '59.96',
#   '중개사소재지': '서울 강남구',
#   '지번': '1282',
#   '지역코드': '11680',
#   '층': '29',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '212,500',
#   '거래유형': '중개거래',
#   '건축년도': '2019',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '개포동',
#   '아파트': '디에이치아너힐즈',
#   '월': '1',
#   '일': '10',
#   '전용면적': '59.7479',
#   '중개사소재지': '서울 강남구',
#   '지번': '138',
#   '지역코드': '11680',
#   '층': '26',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '130,000',
#   '거래유형': '중개거래',
#   '건축년도': '1992',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '개포동',
#   '아파트': '삼익대청아파트',
#   '월': '1',
#   '일': '11',
#   '전용면적': '51.12',
#   '중개사소재지': '서울 강남구',
#   '지번': '12',
#   '지역코드': '11680',
#   '층': '12',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '216,000',
#   '거래유형': '중개거래',
#   '건축년도': '2023',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '개포동',
#   '아파트': '개포자이프레지던스',
#   '월': '1',
#   '일': '12',
#   '전용면적': '59.98',
#   '중개사소재지': '서울 강남구',
#   '지번': '189',
#   '지역코드': '11680',
#   '층': '26',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '113,000',
#   '거래유형': '중개거래',
#   '건축년도': '1992',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '개포동',
#   '아파트': '성원대치2단지아파트',
#   '월': '1',
#   '일': '13',
#   '전용면적': '39.53',
#   '중개사소재지': '서울 강남구',
#   '지번': '12',
#   '지역코드': '11680',
#   '층': '11',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '215,000',
#   '거래유형': '중개거래',
#   '건축년도': '1983',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '개포동',
#   '아파트': '개포주공5단지',
#   '월': '1',
#   '일': '13',
#   '전용면적': '53.98',
#   '중개사소재지': '서울 강남구',
#   '지번': '187',
#   '지역코드': '11680',
#   '층': '8',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '161,000',
#   '거래유형': '직거래',
#   '건축년도': '2019',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '법인',
#   '매수자': '개인',
#   '법정동': '개포동',
#   '아파트': '래미안블레스티지',
#   '월': '1',
#   '일': '15',
#   '전용면적': '49.909',
#   '중개사소재지': None,
#   '지번': '1280',
#   '지역코드': '11680',
#   '층': '12',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '116,000',
#   '거래유형': '중개거래',
#   '건축년도': '1991',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '법정동': '개포동',
#   '아파트': 'SH대치1단지아파트',
#   '월': '1',
#   '일': '17',
#   '전용면적': '25.35',
#   '중개사소재지': '서울 강남구',
#   '지번': '12',
#   '지역코드': '11680',
#   '층': '8',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '209,500',
#   '거래유형': '중개거래',
#   '건축년도': '2019',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '법정동': '개포동',
#   '아파트': '디에이치아너힐즈',
#   '월': '1',
#   '일': '18',
#   '전용면적': '59.8732',
#   '중개사소재지': '서울 강남구',
#   '지번': '138',
#   '지역코드': '11680',
#   '층': '16',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '340,000',
#   '거래유형': '중개거래',
#   '건축년도': '1984',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '개포동',
#   '아파트': '경남2차',
#   '월': '1',
#   '일': '25',
#   '전용면적': '182.2',
#   '중개사소재지': '서울 강남구',
#   '지번': '649',
#   '지역코드': '11680',
#   '층': '10',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '187,000',
#   '거래유형': '중개거래',
#   '건축년도': '2011',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '청담동',
#   '아파트': '청담자이',
#   '월': '1',
#   '일': '2',
#   '전용면적': '49.619',
#   '중개사소재지': '서울 강남구',
#   '지번': '134-38',
#   '지역코드': '11680',
#   '층': '8',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '217,000',
#   '거래유형': '중개거래',
#   '건축년도': '1984',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '청담동',
#   '아파트': '진흥아파트',
#   '월': '1',
#   '일': '5',
#   '전용면적': '109.31',
#   '중개사소재지': '서울 강남구',
#   '지번': '65',
#   '지역코드': '11680',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '350,000',
#   '거래유형': '중개거래',
#   '건축년도': '1999',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '청담동',
#   '아파트': '청담현대3차아파트',
#   '월': '1',
#   '일': '9',
#   '전용면적': '109.53',
#   '중개사소재지': '서울 강남구',
#   '지번': '127-31',
#   '지역코드': '11680',
#   '층': '17',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '163,000',
#   '거래유형': '중개거래',
#   '건축년도': '1988',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '청담동',
#   '아파트': '현대아파트',
#   '월': '1',
#   '일': '11',
#   '전용면적': '84.92',
#   '중개사소재지': '서울 강남구, 서울 강동구',
#   '지번': '23',
#   '지역코드': '11680',
#   '층': '4',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '175,000',
#   '거래유형': '중개거래',
#   '건축년도': '2011',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '청담동',
#   '아파트': '청담자이',
#   '월': '1',
#   '일': '17',
#   '전용면적': '49.639',
#   '중개사소재지': '서울 강남구',
#   '지번': '134-38',
#   '지역코드': '11680',
#   '층': '5',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '165,000',
#   '거래유형': '중개거래',
#   '건축년도': '1988',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '청담동',
#   '아파트': '현대아파트',
#   '월': '1',
#   '일': '19',
#   '전용면적': '84.92',
#   '중개사소재지': '서울 강남구',
#   '지번': '23',
#   '지역코드': '11680',
#   '층': '3',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '200,000',
#   '거래유형': '중개거래',
#   '건축년도': '2011',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '청담동',
#   '아파트': '청담자이',
#   '월': '1',
#   '일': '31',
#   '전용면적': '49.593',
#   '중개사소재지': '서울 강남구',
#   '지번': '134-38',
#   '지역코드': '11680',
#   '층': '18',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '425,000',
#   '거래유형': '중개거래',
#   '건축년도': '2007',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '삼성동',
#   '아파트': '롯데캐슬프레미어',
#   '월': '1',
#   '일': '2',
#   '전용면적': '213.435',
#   '중개사소재지': '서울 강남구',
#   '지번': '11',
#   '지역코드': '11680',
#   '층': '8',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '150,000',
#   '거래유형': '중개거래',
#   '건축년도': '2004',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '삼성동',
#   '아파트': '삼성동대성유니드',
#   '월': '1',
#   '일': '3',
#   '전용면적': '78.69',
#   '중개사소재지': '서울 강남구',
#   '지번': '129',
#   '지역코드': '11680',
#   '층': '6',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '43,000',
#   '거래유형': '중개거래',
#   '건축년도': '2003',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '삼성동',
#   '아파트': 'LG선릉에클라트(A)',
#   '월': '1',
#   '일': '4',
#   '전용면적': '36.16',
#   '중개사소재지': '서울 강남구',
#   '지번': '142-7',
#   '지역코드': '11680',
#   '층': '4',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '900,000',
#   '거래유형': '중개거래',
#   '건축년도': '2004',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '삼성동',
#   '아파트': '아이파크',
#   '월': '1',
#   '일': '9',
#   '전용면적': '175.052',
#   '중개사소재지': '서울 강남구, 서울 송파구',
#   '지번': '87',
#   '지역코드': '11680',
#   '층': '33',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '93,000',
#   '거래유형': '중개거래',
#   '건축년도': '2004',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '삼성동',
#   '아파트': '이안애2차',
#   '월': '1',
#   '일': '10',
#   '전용면적': '64.26',
#   '중개사소재지': '서울 강남구',
#   '지번': '130-6',
#   '지역코드': '11680',
#   '층': '7',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '37,500',
#   '거래유형': '중개거래',
#   '건축년도': '2004',
#   '년': '2024',
#   '동': 'LG선릉에클라트B',
#   '등기일자': '24.02.01',
#   '매도자': '기타',
#   '매수자': '개인',
#   '법정동': '삼성동',
#   '아파트': 'LG선릉에클라트(B)',
#   '월': '1',
#   '일': '10',
#   '전용면적': '36.35',
#   '중개사소재지': '서울 강남구',
#   '지번': '142-3',
#   '지역코드': '11680',
#   '층': '13',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '140,000',
#   '거래유형': '중개거래',
#   '건축년도': '1998',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '법정동': '삼성동',
#   '아파트': '삼성동한솔아파트',
#   '월': '1',
#   '일': '22',
#   '전용면적': '58.57',
#   '중개사소재지': '서울 강남구',
#   '지번': '4-6',
#   '지역코드': '11680',
#   '층': '5',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '300,000',
#   '거래유형': '중개거래',
#   '건축년도': '2007',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '삼성동',
#   '아파트': '롯데캐슬프레미어',
#   '월': '1',
#   '일': '23',
#   '전용면적': '121.931',
#   '중개사소재지': '서울 강남구',
#   '지번': '11',
#   '지역코드': '11680',
#   '층': '13',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '102,600',
#   '거래유형': '중개거래',
#   '건축년도': '2008',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '법정동': '삼성동',
#   '아파트': '삼성동힐스테이트 1단지',
#   '월': '1',
#   '일': '26',
#   '전용면적': '31.402',
#   '중개사소재지': '서울 강남구',
#   '지번': '16-2',
#   '지역코드': '11680',
#   '층': '7',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '233,000',
#   '거래유형': '중개거래',
#   '건축년도': '2018',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '삼성동',
#   '아파트': '삼성동센트럴아이파크',
#   '월': '1',
#   '일': '26',
#   '전용면적': '59.96',
#   '중개사소재지': '서울 강남구',
#   '지번': '188',
#   '지역코드': '11680',
#   '층': '15',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '237,000',
#   '거래유형': '중개거래',
#   '건축년도': '1979',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '은마',
#   '월': '1',
#   '일': '4',
#   '전용면적': '76.79',
#   '중개사소재지': '서울 강남구',
#   '지번': '316',
#   '지역코드': '11680',
#   '층': '4',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '271,500',
#   '거래유형': '중개거래',
#   '건축년도': '1985',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '한보미도맨션2',
#   '월': '1',
#   '일': '5',
#   '전용면적': '84.96',
#   '중개사소재지': '서울 강남구, 서울 송파구',
#   '지번': '511',
#   '지역코드': '11680',
#   '층': '8',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '482,000',
#   '거래유형': '중개거래',
#   '건축년도': '1983',
#   '년': '2024',
#   '동': '111',
#   '등기일자': '24.01.12',
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '한보미도맨션1',
#   '월': '1',
#   '일': '10',
#   '전용면적': '191.07',
#   '중개사소재지': '서울 강남구',
#   '지번': '511',
#   '지역코드': '11680',
#   '층': '6',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '395,000',
#   '거래유형': '중개거래',
#   '건축년도': '1984',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '개포우성2',
#   '월': '1',
#   '일': '11',
#   '전용면적': '127.78',
#   '중개사소재지': '서울 강남구',
#   '지번': '500',
#   '지역코드': '11680',
#   '층': '6',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '269,000',
#   '거래유형': '중개거래',
#   '건축년도': '1985',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '한보미도맨션2',
#   '월': '1',
#   '일': '11',
#   '전용면적': '84.96',
#   '중개사소재지': '서울 강남구',
#   '지번': '511',
#   '지역코드': '11680',
#   '층': '6',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '350,000',
#   '거래유형': '중개거래',
#   '건축년도': '1983',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '한보미도맨션1',
#   '월': '1',
#   '일': '12',
#   '전용면적': '128.01',
#   '중개사소재지': '서울 강남구',
#   '지번': '511',
#   '지역코드': '11680',
#   '층': '5',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '240,000',
#   '거래유형': '중개거래',
#   '건축년도': '1983',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '쌍용대치아파트1동,2동,3동,5동,6동',
#   '월': '1',
#   '일': '12',
#   '전용면적': '83.56',
#   '중개사소재지': '서울 강남구',
#   '지번': '66',
#   '지역코드': '11680',
#   '층': '12',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '35,000',
#   '거래유형': '중개거래',
#   '건축년도': '2003',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '대우아이빌멤버스(891-26)',
#   '월': '1',
#   '일': '12',
#   '전용면적': '35.236',
#   '중개사소재지': '경기 남양주시, 서울 강남구',
#   '지번': '891-26',
#   '지역코드': '11680',
#   '층': '9',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '205,000',
#   '거래유형': '중개거래',
#   '건축년도': '2021',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '대치르엘',
#   '월': '1',
#   '일': '12',
#   '전용면적': '59.9972',
#   '중개사소재지': '서울 강남구',
#   '지번': '1030',
#   '지역코드': '11680',
#   '층': '5',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '23,000',
#   '거래유형': '중개거래',
#   '건축년도': '2004',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '법인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '선릉역대우아이빌(890-49)',
#   '월': '1',
#   '일': '16',
#   '전용면적': '25.42',
#   '중개사소재지': '서울 강남구',
#   '지번': '890-49',
#   '지역코드': '11680',
#   '층': '15',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '397,000',
#   '거래유형': '중개거래',
#   '건축년도': '1983',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '선경1차(1동-7동)',
#   '월': '1',
#   '일': '17',
#   '전용면적': '136.68',
#   '중개사소재지': '서울 강남구, 서울 서초구',
#   '지번': '506',
#   '지역코드': '11680',
#   '층': '12',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '400,000',
#   '거래유형': '중개거래',
#   '건축년도': '1985',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '법정동': '대치동',
#   '아파트': '한보미도맨션2',
#   '월': '1',
#   '일': '17',
#   '전용면적': '84.96',
#   '중개사소재지': '서울 강남구',
#   '지번': '511',
#   '지역코드': '11680',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '280,000',
#   '거래유형': '중개거래',
#   '건축년도': '1983',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '한보미도맨션1',
#   '월': '1',
#   '일': '20',
#   '전용면적': '84.48',
#   '중개사소재지': '서울 강남구',
#   '지번': '511',
#   '지역코드': '11680',
#   '층': '10',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '308,000',
#   '거래유형': '중개거래',
#   '건축년도': '1983',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '쌍용대치아파트1동,2동,3동,5동,6동',
#   '월': '1',
#   '일': '23',
#   '전용면적': '128.03',
#   '중개사소재지': '서울 강남구',
#   '지번': '66',
#   '지역코드': '11680',
#   '층': '4',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '273,000',
#   '거래유형': '중개거래',
#   '건축년도': '1983',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '한보미도맨션1',
#   '월': '1',
#   '일': '26',
#   '전용면적': '84.48',
#   '중개사소재지': '서울 강남구',
#   '지번': '511',
#   '지역코드': '11680',
#   '층': '10',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '390,000',
#   '거래유형': '중개거래',
#   '건축년도': '1983',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '선경1차(1동-7동)',
#   '월': '1',
#   '일': '29',
#   '전용면적': '136.68',
#   '중개사소재지': '서울 강남구',
#   '지번': '506',
#   '지역코드': '11680',
#   '층': '4',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '325,000',
#   '거래유형': '중개거래',
#   '건축년도': '1985',
#   '년': '2024',
#   '동': '202',
#   '등기일자': '24.02.01',
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '대치동',
#   '아파트': '한보미도맨션2',
#   '월': '1',
#   '일': '29',
#   '전용면적': '126.33',
#   '중개사소재지': '서울 강남구',
#   '지번': '511',
#   '지역코드': '11680',
#   '층': '3',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '270,000',
#   '거래유형': '중개거래',
#   '건축년도': '2007',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '신사동',
#   '아파트': '리갈팰리스',
#   '월': '1',
#   '일': '20',
#   '전용면적': '184.63',
#   '중개사소재지': '서울 노원구, 서울 동대문구',
#   '지번': '626',
#   '지역코드': '11680',
#   '층': '2',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '21,000',
#   '거래유형': '직거래',
#   '건축년도': '2013',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '논현동',
#   '아파트': '한양수자인어반게이트',
#   '월': '1',
#   '일': '9',
#   '전용면적': '16.2',
#   '중개사소재지': None,
#   '지번': '221-7',
#   '지역코드': '11680',
#   '층': '6',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '165,000',
#   '거래유형': '중개거래',
#   '건축년도': '2003',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '논현동',
#   '아파트': '동부센트레빌',
#   '월': '1',
#   '일': '13',
#   '전용면적': '84.9875',
#   '중개사소재지': '서울 강남구',
#   '지번': '275',
#   '지역코드': '11680',
#   '층': '14',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '95,214',
#   '거래유형': '직거래',
#   '건축년도': '2021',
#   '년': '2024',
#   '동': None,
#   '등기일자': '24.01.19',
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '논현동',
#   '아파트': '펜트힐루논현',
#   '월': '1',
#   '일': '19',
#   '전용면적': '43.392',
#   '중개사소재지': None,
#   '지번': '211-21',
#   '지역코드': '11680',
#   '층': '14',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '39,000',
#   '거래유형': '중개거래',
#   '건축년도': '1996',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '논현동',
#   '아파트': '거평프리젠',
#   '월': '1',
#   '일': '24',
#   '전용면적': '31.585',
#   '중개사소재지': '서울 강남구',
#   '지번': '196',
#   '지역코드': '11680',
#   '층': '11',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '540,000',
#   '거래유형': '중개거래',
#   '건축년도': '1979',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '압구정동',
#   '아파트': '현대7차(73~77,82,85동)',
#   '월': '1',
#   '일': '3',
#   '전용면적': '157.36',
#   '중개사소재지': '서울 강남구',
#   '지번': '456',
#   '지역코드': '11680',
#   '층': '6',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '520,000',
#   '거래유형': '중개거래',
#   '건축년도': '1976',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '압구정동',
#   '아파트': '현대2차(10,11,20,23,24,25동)',
#   '월': '1',
#   '일': '10',
#   '전용면적': '160.28',
#   '중개사소재지': '서울 강남구',
#   '지번': '369-1',
#   '지역코드': '11680',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '600,000',
#   '거래유형': '중개거래',
#   '건축년도': '1976',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '압구정동',
#   '아파트': '현대2차(10,11,20,23,24,25동)',
#   '월': '1',
#   '일': '13',
#   '전용면적': '160.52',
#   '중개사소재지': '서울 강남구',
#   '지번': '369-1',
#   '지역코드': '11680',
#   '층': '11',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '495,000',
#   '거래유형': '중개거래',
#   '건축년도': '1978',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '압구정동',
#   '아파트': '현대6차(78~81,83,84,86,87동)',
#   '월': '1',
#   '일': '13',
#   '전용면적': '144.7',
#   '중개사소재지': '서울 강남구',
#   '지번': '456',
#   '지역코드': '11680',
#   '층': '7',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '418,000',
#   '거래유형': '중개거래',
#   '건축년도': '1983',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '압구정동',
#   '아파트': '신현대11차',
#   '월': '1',
#   '일': '18',
#   '전용면적': '115.23',
#   '중개사소재지': '서울 강남구',
#   '지번': '433',
#   '지역코드': '11680',
#   '층': '12',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '375,000',
#   '거래유형': '중개거래',
#   '건축년도': '1977',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '압구정동',
#   '아파트': '한양1차(영동한양)',
#   '월': '1',
#   '일': '19',
#   '전용면적': '91.21',
#   '중개사소재지': '서울 강남구',
#   '지번': '490',
#   '지역코드': '11680',
#   '층': '8',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '415,000',
#   '거래유형': '중개거래',
#   '건축년도': '1982',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '압구정동',
#   '아파트': '현대10차(201,202동)',
#   '월': '1',
#   '일': '22',
#   '전용면적': '108.15',
#   '중개사소재지': '서울 강남구',
#   '지번': '436',
#   '지역코드': '11680',
#   '층': '12',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '675,000',
#   '거래유형': '중개거래',
#   '건축년도': '1983',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '압구정동',
#   '아파트': '신현대11차',
#   '월': '1',
#   '일': '24',
#   '전용면적': '183.41',
#   '중개사소재지': '서울 강남구',
#   '지번': '433',
#   '지역코드': '11680',
#   '층': '7',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '134,500',
#   '거래유형': '중개거래',
#   '건축년도': '2013',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '세곡동',
#   '아파트': '강남엘에이치1단지',
#   '월': '1',
#   '일': '8',
#   '전용면적': '84.84',
#   '중개사소재지': '서울 강남구',
#   '지번': '579',
#   '지역코드': '11680',
#   '층': '3',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '119,000',
#   '거래유형': '중개거래',
#   '건축년도': '2013',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '세곡동',
#   '아파트': '강남엘에이치1단지',
#   '월': '1',
#   '일': '16',
#   '전용면적': '59.89',
#   '중개사소재지': '서울 강남구',
#   '지번': '579',
#   '지역코드': '11680',
#   '층': '14',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '115,000',
#   '거래유형': '중개거래',
#   '건축년도': '2014',
#   '년': '2024',
#   '동': '704',
#   '등기일자': '24.01.30',
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '자곡동',
#   '아파트': '강남자곡아이파크',
#   '월': '1',
#   '일': '2',
#   '전용면적': '59.96',
#   '중개사소재지': '서울 강남구',
#   '지번': '602',
#   '지역코드': '11680',
#   '층': '10',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '145,000',
#   '거래유형': '중개거래',
#   '건축년도': '2014',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '자곡동',
#   '아파트': '강남자곡아이파크',
#   '월': '1',
#   '일': '6',
#   '전용면적': '74.97',
#   '중개사소재지': '서울 강남구',
#   '지번': '602',
#   '지역코드': '11680',
#   '층': '12',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '148,000',
#   '거래유형': '중개거래',
#   '건축년도': '2014',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '자곡동',
#   '아파트': '강남한양수자인(4단지)',
#   '월': '1',
#   '일': '9',
#   '전용면적': '84.99',
#   '중개사소재지': '서울 강남구',
#   '지번': '686',
#   '지역코드': '11680',
#   '층': '7',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '113,500',
#   '거래유형': '중개거래',
#   '건축년도': '2014',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '자곡동',
#   '아파트': '강남자곡아이파크',
#   '월': '1',
#   '일': '10',
#   '전용면적': '59.96',
#   '중개사소재지': '서울 강남구',
#   '지번': '602',
#   '지역코드': '11680',
#   '층': '2',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '120,000',
#   '거래유형': '중개거래',
#   '건축년도': '2014',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '자곡동',
#   '아파트': '강남자곡아이파크',
#   '월': '1',
#   '일': '10',
#   '전용면적': '59.96',
#   '중개사소재지': '서울 강남구',
#   '지번': '602',
#   '지역코드': '11680',
#   '층': '8',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '120,000',
#   '거래유형': '중개거래',
#   '건축년도': '2014',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '자곡동',
#   '아파트': '강남자곡아이파크',
#   '월': '1',
#   '일': '23',
#   '전용면적': '59.96',
#   '중개사소재지': '서울 강남구',
#   '지번': '602',
#   '지역코드': '11680',
#   '층': '6',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '122,000',
#   '거래유형': '중개거래',
#   '건축년도': '1994',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '일원동',
#   '아파트': '푸른마을아파트101동~111동',
#   '월': '1',
#   '일': '2',
#   '전용면적': '59.76',
#   '중개사소재지': '서울 강남구',
#   '지번': '719',
#   '지역코드': '11680',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '179,000',
#   '거래유형': '중개거래',
#   '건축년도': '1993',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '일원동',
#   '아파트': '상록수',
#   '월': '1',
#   '일': '3',
#   '전용면적': '74.54',
#   '중개사소재지': '서울 강남구, 서울 중구',
#   '지번': '734',
#   '지역코드': '11680',
#   '층': '5',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '155,000',
#   '거래유형': '중개거래',
#   '건축년도': '1984',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '일원동',
#   '아파트': '개포한신',
#   '월': '1',
#   '일': '5',
#   '전용면적': '82.3',
#   '중개사소재지': '서울 송파구',
#   '지번': '615-1',
#   '지역코드': '11680',
#   '층': '3',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '198,000',
#   '거래유형': '중개거래',
#   '건축년도': '2018',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '일원동',
#   '아파트': '래미안 개포 루체하임',
#   '월': '1',
#   '일': '6',
#   '전용면적': '59.98',
#   '중개사소재지': '서울 강남구',
#   '지번': '741',
#   '지역코드': '11680',
#   '층': '15',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '180,000',
#   '거래유형': '중개거래',
#   '건축년도': '1993',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '일원동',
#   '아파트': '상록수',
#   '월': '1',
#   '일': '8',
#   '전용면적': '74.54',
#   '중개사소재지': '서울 강남구, 서울 서초구',
#   '지번': '734',
#   '지역코드': '11680',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '171,000',
#   '거래유형': '직거래',
#   '건축년도': '1994',
#   '년': '2024',
#   '동': '105',
#   '등기일자': '24.01.30',
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '일원동',
#   '아파트': '샘터마을',
#   '월': '1',
#   '일': '9',
#   '전용면적': '101.97',
#   '중개사소재지': None,
#   '지번': '718',
#   '지역코드': '11680',
#   '층': '13',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '147,000',
#   '거래유형': '중개거래',
#   '건축년도': '1994',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '일원동',
#   '아파트': '푸른마을아파트101동~111동',
#   '월': '1',
#   '일': '17',
#   '전용면적': '59.76',
#   '중개사소재지': '서울 강남구',
#   '지번': '719',
#   '지역코드': '11680',
#   '층': '9',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '193,500',
#   '거래유형': '중개거래',
#   '건축년도': '1984',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '법정동': '일원동',
#   '아파트': '개포한신',
#   '월': '1',
#   '일': '17',
#   '전용면적': '107.6',
#   '중개사소재지': '서울 강남구',
#   '지번': '615-1',
#   '지역코드': '11680',
#   '층': '3',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '140,000',
#   '거래유형': '중개거래',
#   '건축년도': '1994',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '일원동',
#   '아파트': '푸른마을아파트101동~111동',
#   '월': '1',
#   '일': '17',
#   '전용면적': '59.76',
#   '중개사소재지': '서울 강남구, 서울 성북구',
#   '지번': '719',
#   '지역코드': '11680',
#   '층': '14',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '99,000',
#   '거래유형': '중개거래',
#   '건축년도': '1992',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '일원동',
#   '아파트': '수서',
#   '월': '1',
#   '일': '17',
#   '전용면적': '51.76',
#   '중개사소재지': '서울 강남구',
#   '지번': '711',
#   '지역코드': '11680',
#   '층': '11',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '145,000',
#   '거래유형': '중개거래',
#   '건축년도': '1987',
#   '년': '2024',
#   '동': '105',
#   '등기일자': '24.01.18',
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '일원동',
#   '아파트': '우성7',
#   '월': '1',
#   '일': '17',
#   '전용면적': '84.06',
#   '중개사소재지': '서울 강남구',
#   '지번': '615',
#   '지역코드': '11680',
#   '층': '4',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '99,000',
#   '거래유형': '중개거래',
#   '건축년도': '1992',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '일원동',
#   '아파트': '수서',
#   '월': '1',
#   '일': '17',
#   '전용면적': '51.76',
#   '중개사소재지': '경기 의왕시, 서울 강남구',
#   '지번': '711',
#   '지역코드': '11680',
#   '층': '11',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '185,000',
#   '거래유형': '중개거래',
#   '건축년도': '2018',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '법인',
#   '매수자': '법인',
#   '법정동': '일원동',
#   '아파트': '래미안 개포 루체하임',
#   '월': '1',
#   '일': '23',
#   '전용면적': '59.99',
#   '중개사소재지': '서울 강남구, 서울 송파구',
#   '지번': '741',
#   '지역코드': '11680',
#   '층': '9',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '173,500',
#   '거래유형': '중개거래',
#   '건축년도': '1997',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '수서동',
#   '아파트': '삼성',
#   '월': '1',
#   '일': '2',
#   '전용면적': '84.97',
#   '중개사소재지': '서울 강남구',
#   '지번': '747',
#   '지역코드': '11680',
#   '층': '3',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '145,500',
#   '거래유형': '중개거래',
#   '건축년도': '1997',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '수서동',
#   '아파트': '삼성',
#   '월': '1',
#   '일': '2',
#   '전용면적': '59.86',
#   '중개사소재지': '서울 강남구',
#   '지번': '747',
#   '지역코드': '11680',
#   '층': '3',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '90,000',
#   '거래유형': '중개거래',
#   '건축년도': '1993',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '수서동',
#   '아파트': '까치마을',
#   '월': '1',
#   '일': '4',
#   '전용면적': '39.6',
#   '중개사소재지': '서울 강남구',
#   '지번': '746',
#   '지역코드': '11680',
#   '층': '13',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '119,500',
#   '거래유형': '중개거래',
#   '건축년도': '1993',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '수서동',
#   '아파트': '까치마을',
#   '월': '1',
#   '일': '10',
#   '전용면적': '49.5',
#   '중개사소재지': '서울 강남구',
#   '지번': '746',
#   '지역코드': '11680',
#   '층': '14',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '90,000',
#   '거래유형': '중개거래',
#   '건축년도': '1992',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '수서동',
#   '아파트': '신동아',
#   '월': '1',
#   '일': '15',
#   '전용면적': '33.18',
#   '중개사소재지': '서울 강남구',
#   '지번': '736',
#   '지역코드': '11680',
#   '층': '6',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '117,000',
#   '거래유형': '중개거래',
#   '건축년도': '1992',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '수서동',
#   '아파트': '삼익',
#   '월': '1',
#   '일': '17',
#   '전용면적': '49.2',
#   '중개사소재지': '경기 의왕시, 서울 강남구',
#   '지번': '708',
#   '지역코드': '11680',
#   '층': '6',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '118,000',
#   '거래유형': '중개거래',
#   '건축년도': '1992',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '수서동',
#   '아파트': '신동아',
#   '월': '1',
#   '일': '18',
#   '전용면적': '49.96',
#   '중개사소재지': '서울 강남구',
#   '지번': '736',
#   '지역코드': '11680',
#   '층': '9',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '89,000',
#   '거래유형': '중개거래',
#   '건축년도': '1992',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '수서동',
#   '아파트': '신동아',
#   '월': '1',
#   '일': '23',
#   '전용면적': '33.18',
#   '중개사소재지': '서울 강남구',
#   '지번': '736',
#   '지역코드': '11680',
#   '층': '5',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '92,000',
#   '거래유형': '중개거래',
#   '건축년도': '1992',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '법정동': '수서동',
#   '아파트': '신동아',
#   '월': '1',
#   '일': '27',
#   '전용면적': '33.18',
#   '중개사소재지': '서울 강남구',
#   '지번': '736',
#   '지역코드': '11680',
#   '층': '4',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '264,000',
#   '거래유형': '중개거래',
#   '건축년도': '2007',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '도곡동',
#   '아파트': '도곡1차아이파크',
#   '월': '1',
#   '일': '3',
#   '전용면적': '130.259',
#   '중개사소재지': '서울 강남구',
#   '지번': '543-7',
#   '지역코드': '11680',
#   '층': '25',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '177,000',
#   '거래유형': '중개거래',
#   '건축년도': '2016',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '법인',
#   '매수자': '법인',
#   '법정동': '도곡동',
#   '아파트': '한라비발디',
#   '월': '1',
#   '일': '4',
#   '전용면적': '84.8861',
#   '중개사소재지': '서울 강남구',
#   '지번': '972',
#   '지역코드': '11680',
#   '층': '9',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '375,000',
#   '거래유형': '중개거래',
#   '건축년도': '2002',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '도곡동',
#   '아파트': '포스코트',
#   '월': '1',
#   '일': '4',
#   '전용면적': '209.03',
#   '중개사소재지': '서울 강남구',
#   '지번': '164-6',
#   '지역코드': '11680',
#   '층': '9',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '229,000',
#   '거래유형': '중개거래',
#   '건축년도': '1986',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '도곡동',
#   '아파트': '우성사원5',
#   '월': '1',
#   '일': '6',
#   '전용면적': '78.99',
#   '중개사소재지': '서울 강남구',
#   '지번': '463-1',
#   '지역코드': '11680',
#   '층': '7',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '733,000',
#   '거래유형': '중개거래',
#   '건축년도': '2002',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '도곡동',
#   '아파트': '타워팰리스1',
#   '월': '1',
#   '일': '6',
#   '전용면적': '244.66',
#   '중개사소재지': '서울 강남구',
#   '지번': '467',
#   '지역코드': '11680',
#   '층': '54',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '367,500',
#   '거래유형': '중개거래',
#   '건축년도': '1985',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '도곡동',
#   '아파트': '우성4',
#   '월': '1',
#   '일': '6',
#   '전용면적': '152.74',
#   '중개사소재지': '서울 강남구',
#   '지번': '465',
#   '지역코드': '11680',
#   '층': '9',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '570,000',
#   '거래유형': '중개거래',
#   '건축년도': '2006',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '도곡동',
#   '아파트': '이니그마빌-III',
#   '월': '1',
#   '일': '10',
#   '전용면적': '240.55',
#   '중개사소재지': '서울 강남구',
#   '지번': '201',
#   '지역코드': '11680',
#   '층': '7',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '225,000',
#   '거래유형': '중개거래',
#   '건축년도': '1985',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '도곡동',
#   '아파트': '한신(개포)',
#   '월': '1',
#   '일': '11',
#   '전용면적': '59.48',
#   '중개사소재지': '서울 강남구',
#   '지번': '464',
#   '지역코드': '11680',
#   '층': '7',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '184,000',
#   '거래유형': '중개거래',
#   '건축년도': '2006',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '도곡동',
#   '아파트': '도곡렉슬',
#   '월': '1',
#   '일': '13',
#   '전용면적': '59.9772',
#   '중개사소재지': '서울 강남구',
#   '지번': '527',
#   '지역코드': '11680',
#   '층': '16',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '100,000',
#   '거래유형': '중개거래',
#   '건축년도': '2005',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '도곡동',
#   '아파트': '도곡하이빌',
#   '월': '1',
#   '일': '14',
#   '전용면적': '119.33',
#   '중개사소재지': '서울 강남구',
#   '지번': '919-3',
#   '지역코드': '11680',
#   '층': '4',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '497,000',
#   '거래유형': '중개거래',
#   '건축년도': '2002',
#   '년': '2024',
#   '동': '비',
#   '등기일자': '24.01.19',
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '도곡동',
#   '아파트': '타워팰리스1',
#   '월': '1',
#   '일': '15',
#   '전용면적': '222.48',
#   '중개사소재지': '서울 강남구',
#   '지번': '467',
#   '지역코드': '11680',
#   '층': '64',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '400,000',
#   '거래유형': '중개거래',
#   '건축년도': '2004',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '도곡동',
#   '아파트': '타워팰리스3',
#   '월': '1',
#   '일': '17',
#   '전용면적': '163.567',
#   '중개사소재지': '서울 강남구',
#   '지번': '467-29',
#   '지역코드': '11680',
#   '층': '34',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '282,000',
#   '거래유형': '중개거래',
#   '건축년도': '2006',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '법정동': '도곡동',
#   '아파트': '도곡렉슬',
#   '월': '1',
#   '일': '19',
#   '전용면적': '84.9984',
#   '중개사소재지': '서울 강남구',
#   '지번': '527',
#   '지역코드': '11680',
#   '층': '20',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '185,000',
#   '거래유형': '중개거래',
#   '건축년도': '1995',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '도곡동',
#   '아파트': '럭키(963)',
#   '월': '1',
#   '일': '20',
#   '전용면적': '84.97',
#   '중개사소재지': '서울 강남구',
#   '지번': '963',
#   '지역코드': '11680',
#   '층': '4',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '181,000',
#   '거래유형': '중개거래',
#   '건축년도': '1994',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '도곡동',
#   '아파트': '삼성',
#   '월': '1',
#   '일': '23',
#   '전용면적': '73.41',
#   '중개사소재지': '서울 강남구',
#   '지번': '161',
#   '지역코드': '11680',
#   '층': '12',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '48,000',
#   '거래유형': '중개거래',
#   '건축년도': '1999',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '매도자': '개인',
#   '매수자': '개인',
#   '법정동': '도곡동',
#   '아파트': '현대비젼21',
#   '월': '1',
#   '일': '27',
#   '전용면적': '34.995',
#   '중개사소재지': '서울 강남구',
#   '지번': '467-19',
#   '지역코드': '11680',
#   '층': '27',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '481,000',
#   '거래유형': '직거래',
#   '건축년도': '2002',
#   '년': '2024',
#   '동': None,
#   '등기일자': None,
#   '법정동': '도곡동',
#   '아파트': '타워팰리스1',
#   '월': '1',
#   '일': '29',
#   '전용면적': '164.97',
#   '중개사소재지': None,
#   '지번': '467',
#   '지역코드': '11680',
#   '층': '53',
#   '해제사유발생일': None,
#   '해제여부': None}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(data = dat['response']['body']['items']['item'])
df
# Out:
#         거래금액  거래유형  건축년도     년     동      등기일자  매도자  매수자  법정동       아파트  월  \
# 0    289,000  중개거래  2006  2024  None      None   개인   개인  역삼동  역삼I'PARK  1
# 1     70,000  중개거래  2002  2024  None      None   개인   개인  역삼동    역삼동하나빌  1
# 2    295,000  중개거래  2006  2024  None      None   개인   개인  역삼동  역삼I'PARK  1
# 3    215,000  중개거래  2009  2024  None      None   개인   개인  역삼동   래미안그레이튼  1
# 4     65,000   직거래  2003  2024  None  24.01.19   개인   개인  역삼동     노블스위트  1
# ..       ...   ...   ...   ...   ...       ...  ...  ...  ...       ... ..
# 119  282,000  중개거래  2006  2024  None      None  NaN  NaN  도곡동      도곡렉슬  1
# 120  185,000  중개거래  1995  2024  None      None   개인   개인  도곡동   럭키(963)  1
# 121  181,000  중개거래  1994  2024  None      None   개인   개인  도곡동        삼성  1
# 122   48,000  중개거래  1999  2024  None      None   개인   개인  도곡동    현대비젼21  1
# 123  481,000   직거래  2002  2024  None      None  NaN  NaN  도곡동    타워팰리스1  1
#
#       일     전용면적          중개사소재지      지번   지역코드   층 해제사유발생일  해제여부
# 0     4  116.285          서울 강남구  713-11  11680  14    None  None
# 1     5    50.89          서울 강남구  681-26  11680   9    None  None
# 2     5  116.285          서울 강남구  713-11  11680  15    None  None
# 3     6    70.98  서울 강남구, 서울 송파구  763-16  11680  12    None  None
# 4     6    84.85            None     747  11680   5    None  None
# ..   ..      ...             ...     ...    ...  ..     ...   ...
# 119  19  84.9984          서울 강남구     527  11680  20    None  None
# 120  20    84.97          서울 강남구     963  11680   4    None  None
# 121  23    73.41          서울 강남구     161  11680  12    None  None
# 122  27   34.995          서울 강남구  467-19  11680  27    None  None
# 123  29   164.97            None     467  11680  53    None  None
#
# [124 rows x 19 columns]
