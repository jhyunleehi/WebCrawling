# %%
import os
import numpy as np
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\student\\Documents\\Project\\code'

# %%
os.chdir('../data')

# %%
os.listdir()
# Out:
# ['APT_Price_2023.xlsx',
#  'iris.csv',
#  'iris.json',
#  'iris.parquet',
#  'iris.tsv',
#  'iris.xlsx',
#  'Stock_News_202301.xlsx']

# %%
df = pd.read_excel('APT_Price_2023.xlsx')

# %%
df
# Out:
#          거래금액  거래유형  건축년도     년      등기일자  법정동       아파트   월   일      전용면적  \
# 0      24,000   직거래  1999  2023  23.03.06  역삼동   현대휴먼터치빌   1   6   25.9200
# 1      23,000  중개거래  2003  2023  23.01.13  역삼동     진넥스빌2   1  12   23.8500
# 2     280,000  중개거래  2006  2023  23.08.11  역삼동    개나리래미안   1  12  144.5500
# 3      14,000  중개거래  2012  2023  23.01.20  역삼동  요진와이시티미니   1  14   12.9400
# 4     210,000  중개거래  2006  2023  23.04.19  역삼동    개나리래미안   1  19   84.9300
# ...       ...   ...   ...   ...       ...  ...       ...  ..  ..       ...
# 2255  433,000  중개거래  2002  2023       NaN  도곡동    타워팰리스1  12   2  164.9700
# 2256  192,000  중개거래  1978  2023       NaN  도곡동    도곡쌍용예가  12   5  107.5300
# 2257  215,000  중개거래  2006  2023       NaN  도곡동      도곡렉슬  12   6   59.9818
# 2258   41,800  중개거래  1999  2023  23.12.28  도곡동    현대비젼21  12  13   32.6500
# 2259  320,000  중개거래  1985  2023       NaN  도곡동       우성4  12  22  126.4600
#
#       중개사소재지      지번   지역코드   층 해제사유발생일 해제여부
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260 entries, 0 to 2259
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   거래금액     2260 non-null   object
#  1   거래유형     2260 non-null   object
#  2   건축년도     2260 non-null   int64
#  3   년        2260 non-null   int64
#  4   등기일자     1798 non-null   object
#  5   법정동      2260 non-null   object
#  6   아파트      2260 non-null   object
#  7   월        2260 non-null   int64
#  8   일        2260 non-null   int64
#  9   전용면적     2260 non-null   float64
#  10  중개사소재지   2183 non-null   object
#  11  지번       2260 non-null   object
#  12  지역코드     2260 non-null   int64
#  13  층        2260 non-null   int64
#  14  해제사유발생일  104 non-null    object
#  15  해제여부     104 non-null    object
# dtypes: float64(1), int64(6), object(9)
# memory usage: 282.6+ KB

# %%
df.isna().sum()
# Out:
# 거래금액          0
# 거래유형          0
# 건축년도          0
# 년             0
# 등기일자        462
# 법정동           0
# 아파트           0
# 월             0
# 일             0
# 전용면적          0
# 중개사소재지       77
# 지번            0
# 지역코드          0
# 층             0
# 해제사유발생일    2156
# 해제여부       2156
# dtype: int64

# %%
df.fillna(value = 'NULL')
# Out:
#          거래금액  거래유형  건축년도     년      등기일자  법정동       아파트   월   일      전용면적  \
# 0      24,000   직거래  1999  2023  23.03.06  역삼동   현대휴먼터치빌   1   6   25.9200
# 1      23,000  중개거래  2003  2023  23.01.13  역삼동     진넥스빌2   1  12   23.8500
# 2     280,000  중개거래  2006  2023  23.08.11  역삼동    개나리래미안   1  12  144.5500
# 3      14,000  중개거래  2012  2023  23.01.20  역삼동  요진와이시티미니   1  14   12.9400
# 4     210,000  중개거래  2006  2023  23.04.19  역삼동    개나리래미안   1  19   84.9300
# ...       ...   ...   ...   ...       ...  ...       ...  ..  ..       ...
# 2255  433,000  중개거래  2002  2023      NULL  도곡동    타워팰리스1  12   2  164.9700
# 2256  192,000  중개거래  1978  2023      NULL  도곡동    도곡쌍용예가  12   5  107.5300
# 2257  215,000  중개거래  2006  2023      NULL  도곡동      도곡렉슬  12   6   59.9818
# 2258   41,800  중개거래  1999  2023  23.12.28  도곡동    현대비젼21  12  13   32.6500
# 2259  320,000  중개거래  1985  2023      NULL  도곡동       우성4  12  22  126.4600
#
#       중개사소재지      지번   지역코드   층 해제사유발생일  해제여부
# ...

# %%
# shift + tab -> 함수의 설명서 확인
df.dropna(axis = 0)
# Out:
# Empty DataFrame
# Columns: [거래금액, 거래유형, 건축년도, 년, 등기일자, 법정동, 아파트, 월, 일, 전용면적, 중개사소재지, 지번, 지역코드, 층, 해제사유발생일, 해제여부]
# Index: []

# %%
df = df.dropna(axis = 1)

# %%
df.shape
# Out:
# (2260, 12)

# %%
sr = pd.Series(data = ['A', 'B', '', np.nan, 'E'], index = [1, 2, 3, 4, 5])
sr
# Out:
# 1      A
# 2      B
# 3
# 4    NaN
# 5      E
# dtype: object

# %%
sr.isna()
# Out:
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
sr.fillna(value = '')
# Out:
# 1    A
# 2    B
# 3
# 4
# 5    E
# dtype: object

# %%
sr.loc[sr.isna()] = ''

# %%
sr
# Out:
# 1    A
# 2    B
# 3
# 4
# 5    E
# dtype: object

# %%
sr == ''
# Out:
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
sr.loc[sr == ''] = 'NULL'

# %%
sr
# Out:
# 1       A
# 2       B
# 3    NULL
# 4    NULL
# 5       E
# dtype: object

# %%
sr.iloc[2:]
# Out:
# 3    NULL
# 4    NULL
# 5       E
# dtype: object

# %%
pd.Series(data = [1, 2, 3], index = ['A', 'A', 'A'])
# Out:
# A    1
# A    2
# A    3
# dtype: int64

# %%
li = [1, 3, 5, 7, 9]

# %%
li[1:4]
# Out:
# [3, 5, 7]

# %%
li[[1, 2, 3]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 li[[1, 2, 3]]
#
# TypeError: list indices must be integers or slices, not list

# %%
di = {'A': 1, 'B': 3, 'C': 5, 'D': 7, 'E': 9}
di
# Out:
# {'A': 1, 'B': 3, 'C': 5, 'D': 7, 'E': 9}

# %%
di['A']
# Out:
# 1

# %%
sr
# Out:
# 1       A
# 2       B
# 3    NULL
# 4    NULL
# 5       E
# dtype: object

# %%
sr.iloc[0]
# Out:
# 'A'

# %%
sr.iloc[0:2]
# Out:
# 1    A
# 2    B
# dtype: object

# %%
sr.iloc[[2, 0, 2]]
# Out:
# 3    NULL
# 1       A
# 3    NULL
# dtype: object

# %%
sr.loc[1]
# Out:
# 'A'

# %%
sr.loc[1:2]
# Out:
# 1    A
# 2    B
# dtype: object

# %%
sr.loc[[3, 1, 3]]
# Out:
# 3    NULL
# 1       A
# 3    NULL
# dtype: object

# %%
df['지역코드']
# Out:
# 0       11680
# 1       11680
# 2       11680
# 3       11680
# 4       11680
#         ...
# 2255    11680
# 2256    11680
# 2257    11680
# 2258    11680
# 2259    11680
# Name: 지역코드, Length: 2260, dtype: int64

# %%
df[['지역코드']]
# Out:
#        지역코드
# 0     11680
# 1     11680
# 2     11680
# 3     11680
# 4     11680
# ...     ...
# 2255  11680
# 2256  11680
# 2257  11680
# 2258  11680
# 2259  11680
#
# [2260 rows x 1 columns]

# %%
df[['거래금액', '거래유형', '건축년도']]
# Out:
#          거래금액  거래유형  건축년도
# 0      24,000   직거래  1999
# 1      23,000  중개거래  2003
# 2     280,000  중개거래  2006
# 3      14,000  중개거래  2012
# 4     210,000  중개거래  2006
# ...       ...   ...   ...
# 2255  433,000  중개거래  2002
# 2256  192,000  중개거래  1978
# 2257  215,000  중개거래  2006
# 2258   41,800  중개거래  1999
# 2259  320,000  중개거래  1985
#
# [2260 rows x 3 columns]

# %%
# df['거래금액':'건축년도']
df.loc[:, '거래금액':'건축년도']
# Out:
#          거래금액  거래유형  건축년도
# 0      24,000   직거래  1999
# 1      23,000  중개거래  2003
# 2     280,000  중개거래  2006
# 3      14,000  중개거래  2012
# 4     210,000  중개거래  2006
# ...       ...   ...   ...
# 2255  433,000  중개거래  2002
# 2256  192,000  중개거래  1978
# 2257  215,000  중개거래  2006
# 2258   41,800  중개거래  1999
# 2259  320,000  중개거래  1985
#
# [2260 rows x 3 columns]

# %%
df.drop(columns = '지역코드')
# Out:
#          거래금액  거래유형  건축년도     년  법정동       아파트   월   일      전용면적      지번   층
# 0      24,000   직거래  1999  2023  역삼동   현대휴먼터치빌   1   6   25.9200  606-18  10
# 1      23,000  중개거래  2003  2023  역삼동     진넥스빌2   1  12   23.8500  706-24  10
# 2     280,000  중개거래  2006  2023  역삼동    개나리래미안   1  12  144.5500     754  17
# 3      14,000  중개거래  2012  2023  역삼동  요진와이시티미니   1  14   12.9400   727-9   4
# 4     210,000  중개거래  2006  2023  역삼동    개나리래미안   1  19   84.9300     754   9
# ...       ...   ...   ...   ...  ...       ...  ..  ..       ...     ...  ..
# 2255  433,000  중개거래  2002  2023  도곡동    타워팰리스1  12   2  164.9700     467  18
# 2256  192,000  중개거래  1978  2023  도곡동    도곡쌍용예가  12   5  107.5300     933   8
# 2257  215,000  중개거래  2006  2023  도곡동      도곡렉슬  12   6   59.9818     527  19
# 2258   41,800  중개거래  1999  2023  도곡동    현대비젼21  12  13   32.6500  467-19  23
# 2259  320,000  중개거래  1985  2023  도곡동       우성4  12  22  126.4600     465   8
#
# [2260 rows x 11 columns]

# %%
df.head(n = 5)
# Out:
#       거래금액  거래유형  건축년도     년  법정동       아파트  월   일    전용면적      지번   지역코드   층
# 0   24,000   직거래  1999  2023  역삼동   현대휴먼터치빌  1   6   25.92  606-18  11680  10
# 1   23,000  중개거래  2003  2023  역삼동     진넥스빌2  1  12   23.85  706-24  11680  10
# 2  280,000  중개거래  2006  2023  역삼동    개나리래미안  1  12  144.55     754  11680  17
# 3   14,000  중개거래  2012  2023  역삼동  요진와이시티미니  1  14   12.94   727-9  11680   4
# 4  210,000  중개거래  2006  2023  역삼동    개나리래미안  1  19   84.93     754  11680   9

# %%
df = df.drop(columns = ['지역코드', '거래유형'])

# %%
df.head(n = 5)
# Out:
#       거래금액  건축년도     년  법정동       아파트  월   일    전용면적      지번   층
# 0   24,000  1999  2023  역삼동   현대휴먼터치빌  1   6   25.92  606-18  10
# 1   23,000  2003  2023  역삼동     진넥스빌2  1  12   23.85  706-24  10
# 2  280,000  2006  2023  역삼동    개나리래미안  1  12  144.55     754  17
# 3   14,000  2012  2023  역삼동  요진와이시티미니  1  14   12.94   727-9   4
# 4  210,000  2006  2023  역삼동    개나리래미안  1  19   84.93     754   9

# %%
df.rename(columns = {'년': '거래년도', '월': '거래월', '일': '거래일'})
# Out:
#          거래금액  건축년도  거래년도  법정동       아파트  거래월  거래일      전용면적      지번   층
# 0      24,000  1999  2023  역삼동   현대휴먼터치빌    1    6   25.9200  606-18  10
# 1      23,000  2003  2023  역삼동     진넥스빌2    1   12   23.8500  706-24  10
# 2     280,000  2006  2023  역삼동    개나리래미안    1   12  144.5500     754  17
# 3      14,000  2012  2023  역삼동  요진와이시티미니    1   14   12.9400   727-9   4
# 4     210,000  2006  2023  역삼동    개나리래미안    1   19   84.9300     754   9
# ...       ...   ...   ...  ...       ...  ...  ...       ...     ...  ..
# 2255  433,000  2002  2023  도곡동    타워팰리스1   12    2  164.9700     467  18
# 2256  192,000  1978  2023  도곡동    도곡쌍용예가   12    5  107.5300     933   8
# 2257  215,000  2006  2023  도곡동      도곡렉슬   12    6   59.9818     527  19
# 2258   41,800  1999  2023  도곡동    현대비젼21   12   13   32.6500  467-19  23
# 2259  320,000  1985  2023  도곡동       우성4   12   22  126.4600     465   8
#
# [2260 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['거래금액', '건축년도', '년', '법정동', '아파트', '월', '일', '전용면적', '지번', '층'], dtype='object')

# %%
df.columns = ['거래금액', '건축년도', '거래년도', '법정동', '아파트', 
              '거래월', '거래일', '전용면적', '지번', '층']

# %%
df.head()
# Out:
#       거래금액  건축년도  거래년도  법정동       아파트  거래월  거래일    전용면적      지번   층
# 0   24,000  1999  2023  역삼동   현대휴먼터치빌    1    6   25.92  606-18  10
# 1   23,000  2003  2023  역삼동     진넥스빌2    1   12   23.85  706-24  10
# 2  280,000  2006  2023  역삼동    개나리래미안    1   12  144.55     754  17
# 3   14,000  2012  2023  역삼동  요진와이시티미니    1   14   12.94   727-9   4
# 4  210,000  2006  2023  역삼동    개나리래미안    1   19   84.93     754   9

# %%
df['거래금액'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df['거래금액'].mean()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:6221, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6213 @doc(make_doc("mean", ndim=1))
#    6214 def mean(
#    6215     self,
#    (...)
#    6219     **kwargs,
#    6220 ):
# -> 6221     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:11978, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11971 def mean(
#   11972     self,
#   11973     axis: Axis | None = 0,
#    (...)
#   11976     **kwargs,
#   11977 ) -> Series | float:
# > 11978     return self._stat_function(
#   11979         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
# ...

# %%
df['거래금액'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df['거래금액'].astype(int)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
# ...

# %%
df['거래금액'] = df['거래금액'].str.replace(pat = ',', repl = '').astype('int64')

# %%
df['거래금액'].mean()
# Out:
# 216656.23407079646

# %%
df.dtypes
# Out:
# 거래금액      int64
# 건축년도      int64
# 거래년도      int64
# 법정동      object
# 아파트      object
# 거래월       int64
# 거래일       int64
# 전용면적    float64
# 지번       object
# 층         int64
# dtype: object

# %%
df.head()
# Out:
#      거래금액  건축년도  거래년도  법정동       아파트  거래월  거래일    전용면적      지번   층
# 0   24000  1999  2023  역삼동   현대휴먼터치빌    1    6   25.92  606-18  10
# 1   23000  2003  2023  역삼동     진넥스빌2    1   12   23.85  706-24  10
# 2  280000  2006  2023  역삼동    개나리래미안    1   12  144.55     754  17
# 3   14000  2012  2023  역삼동  요진와이시티미니    1   14   12.94   727-9   4
# 4  210000  2006  2023  역삼동    개나리래미안    1   19   84.93     754   9

# %%
cols = ['거래년도', '거래월', '거래일']
df[cols]
# Out:
#       거래년도  거래월  거래일
# 0     2023    1    6
# 1     2023    1   12
# 2     2023    1   12
# 3     2023    1   14
# 4     2023    1   19
# ...    ...  ...  ...
# 2255  2023   12    2
# 2256  2023   12    5
# 2257  2023   12    6
# 2258  2023   12   13
# 2259  2023   12   22
#
# [2260 rows x 3 columns]

# %%
df[cols] = df[cols].astype(str)

# %%
df.dtypes
# Out:
# 거래금액      int64
# 건축년도      int64
# 거래년도     object
# 법정동      object
# 아파트      object
# 거래월      object
# 거래일      object
# 전용면적    float64
# 지번       object
# 층         int64
# dtype: object

# %%
df['거래일자'] = df['거래년도'] + '-' + df['거래월'] + '-' + df['거래일']

# %%
df.head()
# Out:
#      거래금액  건축년도  거래년도  법정동       아파트 거래월 거래일    전용면적      지번   층       거래일자
# 0   24000  1999  2023  역삼동   현대휴먼터치빌   1   6   25.92  606-18  10   2023-1-6
# 1   23000  2003  2023  역삼동     진넥스빌2   1  12   23.85  706-24  10  2023-1-12
# 2  280000  2006  2023  역삼동    개나리래미안   1  12  144.55     754  17  2023-1-12
# 3   14000  2012  2023  역삼동  요진와이시티미니   1  14   12.94   727-9   4  2023-1-14
# 4  210000  2006  2023  역삼동    개나리래미안   1  19   84.93     754   9  2023-1-19

# %%
# df['거래일자'] = df['거래일자'].astype('datetime64[ns]')
df = df.astype(dtype = {'거래일자': 'datetime64[ns]'})

# %%
df.dtypes
# Out:
# 거래금액             int64
# 건축년도             int64
# 거래년도            object
# 법정동             object
# 아파트             object
# 거래월             object
# 거래일             object
# 전용면적           float64
# 지번              object
# 층                int64
# 거래일자    datetime64[ns]
# dtype: object

# %%
date = '2000년 1월 1일'

# %%
pd.Series(data = date).astype('datetime64[ns]')
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 pd.Series(data = date).astype('datetime64[ns]')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# ...

# %%
birth = pd.to_datetime(arg = date, format = '%Y년 %m월 %d일')

# %%
birth
# Out:
# Timestamp('2000-01-01 00:00:00')

# %%
birth.timestamp()
# Out:
# 946684800.0

# %%
today = pd.Timestamp.today()
today
# Out:
# Timestamp('2024-02-20 13:38:15.218223')

# %%
dtGap = today - birth

# %%
dtGap.days * 3 * 8000
# Out:
# 211584000

# %%
dtGap.seconds
# Out:
# 49095

# %%
df['거래일자'].dt.year
# Out:
# 0       2023
# 1       2023
# 2       2023
# 3       2023
# 4       2023
#         ...
# 2255    2023
# 2256    2023
# 2257    2023
# 2258    2023
# 2259    2023
# Name: 거래일자, Length: 2260, dtype: int32

# %%
df['거래일자'].dt.month
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 2255    12
# 2256    12
# 2257    12
# 2258    12
# 2259    12
# Name: 거래일자, Length: 2260, dtype: int32

# %%
df['거래일자'].dt.day
# Out:
# 0        6
# 1       12
# 2       12
# 3       14
# 4       19
#         ..
# 2255     2
# 2256     5
# 2257     6
# 2258    13
# 2259    22
# Name: 거래일자, Length: 2260, dtype: int32

# %%
df['거래일자'].dt.day_name()
# Out:
# 0          Friday
# 1        Thursday
# 2        Thursday
# 3        Saturday
# 4        Thursday
#           ...
# 2255     Saturday
# 2256      Tuesday
# 2257    Wednesday
# 2258    Wednesday
# 2259       Friday
# Name: 거래일자, Length: 2260, dtype: object

# %%
df['거래일자'].dt.day_name(locale = 'ko_KR')
# Out:
# 0       금요일
# 1       목요일
# 2       목요일
# 3       토요일
# 4       목요일
#        ...
# 2255    토요일
# 2256    화요일
# 2257    수요일
# 2258    수요일
# 2259    금요일
# Name: 거래일자, Length: 2260, dtype: object

# %%
df['거래월'].str.zfill(2)
# Out:
# 0       01
# 1       01
# 2       01
# 3       01
# 4       01
#         ..
# 2255    12
# 2256    12
# 2257    12
# 2258    12
# 2259    12
# Name: 거래월, Length: 2260, dtype: object

# %%
df['거래일자'].dt.strftime(date_format = '%a %b %d, %Y')
# Out:
# 0       Fri Jan 06, 2023
# 1       Thu Jan 12, 2023
# 2       Thu Jan 12, 2023
# 3       Sat Jan 14, 2023
# 4       Thu Jan 19, 2023
#               ...
# 2255    Sat Dec 02, 2023
# 2256    Tue Dec 05, 2023
# 2257    Wed Dec 06, 2023
# 2258    Wed Dec 13, 2023
# 2259    Fri Dec 22, 2023
# Name: 거래일자, Length: 2260, dtype: object

# %%
cond = df['거래금액'] >= 500000
cond
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2255    False
# 2256    False
# 2257    False
# 2258    False
# 2259    False
# Name: 거래금액, Length: 2260, dtype: bool

# %%
df.loc[cond, :]
# Out:
#         거래금액  건축년도  거래년도   법정동                       아파트 거래월 거래일     전용면적  \
# 226   580000  1978  2023  압구정동  현대6차(78~81,83,84,86,87동)   2  14  157.360
# 362   821000  2006  2023   청담동                상지리츠빌카일룸2차   3  18  244.320
# 403   600000  2004  2023   신사동                  압구정하이츠파크   3  17  213.050
# 411   580000  1982  2023  압구정동                    신현대12차   3   3  182.950
# 412   580000  1982  2023  압구정동                    신현대12차   3   3  182.950
# ...      ...   ...   ...   ...                       ...  ..  ..      ...
# 2128  500000  2017  2023   청담동                    더갤러리파크  11   1  180.580
# 2140  599000  2004  2023   삼성동                      아이파크  11  23  145.046
# 2169  500000  1979  2023  압구정동        현대7차(73~77,82,85동)  11  29  144.200
# 2222  530000  2017  2023   청담동                    더갤러리파크  12   1  163.910
# 2244  515000  1980  2023  압구정동         현대8차(성수현대:91~95동)  12   1  163.670
#
#           지번   층       거래일자
# 226      456   4 2023-02-14
# ...

# %%
pd.Series([True, True, False]) & pd.Series([True, False, False])
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
pd.Series([True, True, False]) | pd.Series([True, False, False])
# Out:
# 0     True
# 1     True
# 2    False
# dtype: bool

# %%
~ pd.Series([True, True, False])
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
cond = (df['거래금액'] < 500000) & (df['층'] >= 25)

# %%
df.loc[cond, :]
# Out:
#         거래금액  건축년도  거래년도  법정동       아파트 거래월 거래일     전용면적      지번   층  \
# 140   250000  2019  2023  개포동  래미안블레스티지   2   4   84.940    1280  27
# 160   315000  2019  2023  개포동  래미안블레스티지   2  16   99.991    1280  27
# 180   330000  2011  2023  청담동      청담자이   2  15   89.115  134-38  32
# 246   253000  2021  2023  일원동  디에이치자이개포   2  10   84.730     743  28
# 252   253000  2021  2023  일원동  디에이치자이개포   2  18   84.730     743  28
# ...      ...   ...   ...  ...       ...  ..  ..      ...     ...  ..
# 2184  190000  2021  2023  일원동  디에이치자이개포  11  18   84.940     743  33
# 2205  375000  2002  2023  도곡동    타워팰리스1  11  11  137.240     467  42
# 2206  495000  2002  2023  도곡동    타워팰리스1  11  13  164.970     467  31
# 2210  315000  2003  2023  도곡동    타워팰리스2  11  24  115.630  467-17  25
# 2248  270000  2021  2023  일원동  디에이치자이개포  12   2   84.730     743  27
#
#            거래일자
# 140  2023-02-04
# 160  2023-02-16
# 180  2023-02-15
# 246  2023-02-10
# 252  2023-02-18
# ...         ...
# ...

# %%
10 & 12
# Out:
# 8

# %%
df.loc[df['법정동'] == '청담동']
# Out:
#         거래금액  건축년도  거래년도  법정동         아파트 거래월 거래일     전용면적      지번   층  \
# 41    300000  1995  2023  청담동          목화   1   5  133.970   105-6   6
# 42    265000  2011  2023  청담동  청담4차이-편한세상   1   5  136.410   28-20   9
# 43    280000  2011  2023  청담동        청담자이   1  17   82.365  134-38  19
# 44    212000  1999  2023  청담동     삼성청담아파트   1  30  114.830      42  14
# 179   207000  1999  2023  청담동   삼성청담공원아파트   2   7  107.220      60   1
# ...      ...   ...   ...  ...         ...  ..  ..      ...     ...  ..
# 2135  231000  1999  2023  청담동   청담현대3차아파트  11  27   85.000  127-31   9
# 2222  530000  2017  2023  청담동      더갤러리파크  12   1  163.910    54-5   5
# 2223  240000  2002  2023  청담동  청담대림이-편한세상  12   1  134.240   30-33   7
# 2224   49000  2015  2023  청담동      청담아르지움  12   2   25.650      32   4
# 2225  350000  1992  2023  청담동  씨티2차(201동)  12   4  133.950  104-19  11
#
#            거래일자
# 41   2023-01-05
# 42   2023-01-05
# 43   2023-01-17
# 44   2023-01-30
# 179  2023-02-07
# ...

# %%
df.loc[(df['법정동'] == '청담동') | (df['법정동'] == '삼성동')]
# Out:
#         거래금액  건축년도  거래년도  법정동          아파트 거래월 거래일     전용면적      지번   층  \
# 41    300000  1995  2023  청담동           목화   1   5  133.970   105-6   6
# 42    265000  2011  2023  청담동   청담4차이-편한세상   1   5  136.410   28-20   9
# 43    280000  2011  2023  청담동         청담자이   1  17   82.365  134-38  19
# 44    212000  1999  2023  청담동      삼성청담아파트   1  30  114.830      42  14
# 45     33000  2003  2023  삼성동  LG선릉에클라트(A)   1   9   36.160   142-7   4
# ...      ...   ...   ...  ...          ...  ..  ..      ...     ...  ..
# 2226  253000  2003  2023  삼성동       쌍용플래티넘  12   4  154.770     117  15
# 2227  259300  2008  2023  삼성동   현대힐스테이트2단지  12   7   84.236      50  13
# 2228  280000  1998  2023  삼성동       풍림(1차)  12  11  113.000     106  12
# 2229  167000  1998  2023  삼성동        서광아파트  12  18   59.670       2  16
# 2230   46000  2003  2023  삼성동        SM드림빌  12  18   52.790   29-11   1
#
#            거래일자
# 41   2023-01-05
# 42   2023-01-05
# 43   2023-01-17
# 44   2023-01-30
# ...

# %%
df.loc[df['법정동'].isin(values = ['청담동', '삼성동'])]
# Out:
#         거래금액  건축년도  거래년도  법정동          아파트 거래월 거래일     전용면적      지번   층  \
# 41    300000  1995  2023  청담동           목화   1   5  133.970   105-6   6
# 42    265000  2011  2023  청담동   청담4차이-편한세상   1   5  136.410   28-20   9
# 43    280000  2011  2023  청담동         청담자이   1  17   82.365  134-38  19
# 44    212000  1999  2023  청담동      삼성청담아파트   1  30  114.830      42  14
# 45     33000  2003  2023  삼성동  LG선릉에클라트(A)   1   9   36.160   142-7   4
# ...      ...   ...   ...  ...          ...  ..  ..      ...     ...  ..
# 2226  253000  2003  2023  삼성동       쌍용플래티넘  12   4  154.770     117  15
# 2227  259300  2008  2023  삼성동   현대힐스테이트2단지  12   7   84.236      50  13
# 2228  280000  1998  2023  삼성동       풍림(1차)  12  11  113.000     106  12
# 2229  167000  1998  2023  삼성동        서광아파트  12  18   59.670       2  16
# 2230   46000  2003  2023  삼성동        SM드림빌  12  18   52.790   29-11   1
#
#            거래일자
# 41   2023-01-05
# 42   2023-01-05
# 43   2023-01-17
# 44   2023-01-30
# ...

# %%
df.loc[(df['법정동'] == '청담동') | (df['법정동'] == '삼성동') | (df['법정동'] == '압구정동')]
# Out:
#         거래금액  건축년도  거래년도   법정동                       아파트 거래월 거래일     전용면적  \
# 41    300000  1995  2023   청담동                        목화   1   5  133.970
# 42    265000  2011  2023   청담동                청담4차이-편한세상   1   5  136.410
# 43    280000  2011  2023   청담동                      청담자이   1  17   82.365
# 44    212000  1999  2023   청담동                   삼성청담아파트   1  30  114.830
# 45     33000  2003  2023   삼성동               LG선릉에클라트(A)   1   9   36.160
# ...      ...   ...   ...   ...                       ...  ..  ..      ...
# 2229  167000  1998  2023   삼성동                     서광아파트  12  18   59.670
# 2230   46000  2003  2023   삼성동                     SM드림빌  12  18   52.790
# 2244  515000  1980  2023  압구정동         현대8차(성수현대:91~95동)  12   1  163.670
# 2245  490000  1978  2023  압구정동  현대6차(78~81,83,84,86,87동)  12   5  144.700
# 2246  390000  1982  2023  압구정동                     신현대9차  12   5  111.380
#
#           지번   층       거래일자
# 41     105-6   6 2023-01-05
# ...

# %%
df.loc[df['법정동'].isin(values = ['청담동', '삼성동', '압구정동'])]
# Out:
#         거래금액  건축년도  거래년도   법정동                       아파트 거래월 거래일     전용면적  \
# 41    300000  1995  2023   청담동                        목화   1   5  133.970
# 42    265000  2011  2023   청담동                청담4차이-편한세상   1   5  136.410
# 43    280000  2011  2023   청담동                      청담자이   1  17   82.365
# 44    212000  1999  2023   청담동                   삼성청담아파트   1  30  114.830
# 45     33000  2003  2023   삼성동               LG선릉에클라트(A)   1   9   36.160
# ...      ...   ...   ...   ...                       ...  ..  ..      ...
# 2229  167000  1998  2023   삼성동                     서광아파트  12  18   59.670
# 2230   46000  2003  2023   삼성동                     SM드림빌  12  18   52.790
# 2244  515000  1980  2023  압구정동         현대8차(성수현대:91~95동)  12   1  163.670
# 2245  490000  1978  2023  압구정동  현대6차(78~81,83,84,86,87동)  12   5  144.700
# 2246  390000  1982  2023  압구정동                     신현대9차  12   5  111.380
#
#           지번   층       거래일자
# 41     105-6   6 2023-01-05
# ...

# %%
df.loc[df['법정동'].str.contains(pat = '(청담|삼성|압구정)동')]
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_6064\636699866.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['법정동'].str.contains(pat = '(청담|삼성|압구정)동')]
#         거래금액  건축년도  거래년도   법정동                       아파트 거래월 거래일     전용면적  \
# 41    300000  1995  2023   청담동                        목화   1   5  133.970
# 42    265000  2011  2023   청담동                청담4차이-편한세상   1   5  136.410
# 43    280000  2011  2023   청담동                      청담자이   1  17   82.365
# 44    212000  1999  2023   청담동                   삼성청담아파트   1  30  114.830
# 45     33000  2003  2023   삼성동               LG선릉에클라트(A)   1   9   36.160
# ...      ...   ...   ...   ...                       ...  ..  ..      ...
# 2229  167000  1998  2023   삼성동                     서광아파트  12  18   59.670
# 2230   46000  2003  2023   삼성동                     SM드림빌  12  18   52.790
# ...

# %%
cond = (df['법정동'] == '압구정동') & (df['거래금액'] >= 500000)
df.loc[cond].shape
# Out:
# (44, 11)

# %%
cond1 = (df['법정동'] == '압구정동')
cond2 = (df['거래금액'] >= 500000)
df.loc[cond1 & cond2].shape
# Out:
# (44, 11)

# %%
df.head()
# Out:
#      거래금액  건축년도  거래년도  법정동       아파트 거래월 거래일    전용면적      지번   층       거래일자
# 0   24000  1999  2023  역삼동   현대휴먼터치빌   1   6   25.92  606-18  10 2023-01-06
# 1   23000  2003  2023  역삼동     진넥스빌2   1  12   23.85  706-24  10 2023-01-12
# 2  280000  2006  2023  역삼동    개나리래미안   1  12  144.55     754  17 2023-01-12
# 3   14000  2012  2023  역삼동  요진와이시티미니   1  14   12.94   727-9   4 2023-01-14
# 4  210000  2006  2023  역삼동    개나리래미안   1  19   84.93     754   9 2023-01-19

# %%
df['평당금액'] = df['거래금액'] / df['전용면적'] * 3.3

# %%
df.head()
# Out:
#      거래금액  건축년도  거래년도  법정동       아파트 거래월 거래일    전용면적      지번   층       거래일자  \
# 0   24000  1999  2023  역삼동   현대휴먼터치빌   1   6   25.92  606-18  10 2023-01-06
# 1   23000  2003  2023  역삼동     진넥스빌2   1  12   23.85  706-24  10 2023-01-12
# 2  280000  2006  2023  역삼동    개나리래미안   1  12  144.55     754  17 2023-01-12
# 3   14000  2012  2023  역삼동  요진와이시티미니   1  14   12.94   727-9   4 2023-01-14
# 4  210000  2006  2023  역삼동    개나리래미안   1  19   84.93     754   9 2023-01-19
#
#           평당금액
# 0  3055.555556
# 1  3182.389937
# 2  6392.251816
# 3  3570.324575
# 4  8159.660897

# %%
df['거래금액'] = df['거래금액'] / 10000

# %%
df.head()
# Out:
#    거래금액  건축년도  거래년도  법정동       아파트 거래월 거래일    전용면적      지번   층       거래일자  \
# 0   2.4  1999  2023  역삼동   현대휴먼터치빌   1   6   25.92  606-18  10 2023-01-06
# 1   2.3  2003  2023  역삼동     진넥스빌2   1  12   23.85  706-24  10 2023-01-12
# 2  28.0  2006  2023  역삼동    개나리래미안   1  12  144.55     754  17 2023-01-12
# 3   1.4  2012  2023  역삼동  요진와이시티미니   1  14   12.94   727-9   4 2023-01-14
# 4  21.0  2006  2023  역삼동    개나리래미안   1  19   84.93     754   9 2023-01-19
#
#           평당금액
# 0  3055.555556
# 1  3182.389937
# 2  6392.251816
# 3  3570.324575
# 4  8159.660897

# %%
df['거래년도'] = df['거래년도'].astype(int)

# %%
df['경과년수'] = df['거래년도'] - df['건축년도']

# %%
df.head()
# Out:
#    거래금액  건축년도  거래년도  법정동       아파트 거래월 거래일    전용면적      지번   층       거래일자  \
# 0   2.4  1999  2023  역삼동   현대휴먼터치빌   1   6   25.92  606-18  10 2023-01-06
# 1   2.3  2003  2023  역삼동     진넥스빌2   1  12   23.85  706-24  10 2023-01-12
# 2  28.0  2006  2023  역삼동    개나리래미안   1  12  144.55     754  17 2023-01-12
# 3   1.4  2012  2023  역삼동  요진와이시티미니   1  14   12.94   727-9   4 2023-01-14
# 4  21.0  2006  2023  역삼동    개나리래미안   1  19   84.93     754   9 2023-01-19
#
#           평당금액  경과년수
# 0  3055.555556    24
# 1  3182.389937    20
# 2  6392.251816    17
# 3  3570.324575    11
# 4  8159.660897    17

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.rc(group = 'font', family = 'Malgun Gothic')

# %%
sns.lineplot(data = df, x = '경과년수', y = '거래금액');

# %%
cond = (df['평당금액'] >= 5000)

# %%
df['금액구간'] = np.where(cond, '5천 이상', '5천 미만')

# %%
df.head()
# Out:
#    거래금액  건축년도  거래년도  법정동       아파트 거래월 거래일    전용면적      지번   층       거래일자  \
# 0   2.4  1999  2023  역삼동   현대휴먼터치빌   1   6   25.92  606-18  10 2023-01-06
# 1   2.3  2003  2023  역삼동     진넥스빌2   1  12   23.85  706-24  10 2023-01-12
# 2  28.0  2006  2023  역삼동    개나리래미안   1  12  144.55     754  17 2023-01-12
# 3   1.4  2012  2023  역삼동  요진와이시티미니   1  14   12.94   727-9   4 2023-01-14
# 4  21.0  2006  2023  역삼동    개나리래미안   1  19   84.93     754   9 2023-01-19
#
#           평당금액  경과년수   금액구간
# 0  3055.555556    24  5천 미만
# 1  3182.389937    20  5천 미만
# 2  6392.251816    17  5천 이상
# 3  3570.324575    11  5천 미만
# 4  8159.660897    17  5천 이상

# %%
np.where(df['거래금액'] >= 5000, 
         '5천 이상', 
         np.where(df['거래금액'] >= 1000, 
                  '1천 이상', 
                  '1천 미만'))

# %%
np.select(
    condlist = [df['거래금액'] >= 5000, df['거래금액'] >= 1000, df['거래금액'] >= 0], 
    choicelist = ['5천 이상', '1천 이상', '1천 미만']
)

# %%
df['층'].sort_values()
# Out:
# 1640     1
# 917      1
# 769      1
# 239      1
# 1096     1
#         ..
# 294     53
# 1482    55
# 1759    58
# 2092    58
# 1746    62
# Name: 층, Length: 2260, dtype: int64

# %%
df['층'].sort_values(ascending=False)
# Out:
# 1746    62
# 2092    58
# 1759    58
# 1482    55
# 294     53
#         ..
# 740      1
# 2100     1
# 1589     1
# 769      1
# 1742     1
# Name: 층, Length: 2260, dtype: int64

# %%
df.sort_values(by = '층')
# Out:
#        거래금액  건축년도  거래년도   법정동               아파트 거래월 거래일     전용면적      지번   층  \
# 1640  62.50  1983  2023  압구정동            신현대11차   8   3  183.410     433   1
# 917    8.70  1992  2023   수서동               신동아   5  26   33.180     736   1
# 769   41.00  2001  2023   청담동           대우리츠카운티   5  17  211.720  117-22   1
# 239   11.10  1994  2023   일원동  푸른마을아파트101동~111동   2   4   59.760     719   1
# 1096  22.75  1999  2023   대치동              대치현대   6  20  101.600     974   1
# ...     ...   ...   ...   ...               ...  ..  ..      ...     ...  ..
# 294   35.50  2004  2023   도곡동            타워팰리스3   2  21  141.648  467-29  53
# 1482  99.00  2002  2023   도곡동            타워팰리스1   7  31  301.470     467  55
# 1759  39.00  2004  2023   도곡동            타워팰리스3   8  30  141.706  467-29  58
# 2092  49.70  2002  2023   도곡동            타워팰리스1  10   9  164.970     467  58
# 1746  67.00  2004  2023   도곡동            타워팰리스3   8  18  244.224  467-29  62
#
#            거래일자          평당금액  경과년수   금액구간
# ...

# %%
df.sort_values(by = '층', ascending = False)
# Out:
#       거래금액  건축년도  거래년도  법정동      아파트 거래월 거래일     전용면적      지번   층       거래일자  \
# 1746  67.0  2004  2023  도곡동   타워팰리스3   8  18  244.224  467-29  62 2023-08-18
# 2092  49.7  2002  2023  도곡동   타워팰리스1  10   9  164.970     467  58 2023-10-09
# 1759  39.0  2004  2023  도곡동   타워팰리스3   8  30  141.706  467-29  58 2023-08-30
# 1482  99.0  2002  2023  도곡동   타워팰리스1   7  31  301.470     467  55 2023-07-31
# 294   35.5  2004  2023  도곡동   타워팰리스3   2  21  141.648  467-29  53 2023-02-21
# ...    ...   ...   ...  ...      ...  ..  ..      ...     ...  ..        ...
# 740   18.0  1983  2023  개포동  개포주공6단지   5  13   53.060     185   1 2023-05-13
# 2100  18.4  1995  2023  도곡동  럭키(963)  10  26   84.970     963   1 2023-10-26
# 1589  39.0  1984  2023  대치동    개포우성2   8   2  127.780     500   1 2023-08-02
# 769   41.0  2001  2023  청담동  대우리츠카운티   5  17  211.720  117-22   1 2023-05-17
# 1742  15.2  2006  2023  도곡동    현대그린1   8  12   84.720     964   1 2023-08-12
#
#               평당금액  경과년수   금액구간
# ...

# %%
df.sort_values(by = ['층', '거래금액'], ascending = False)
# Out:
#        거래금액  건축년도  거래년도  법정동       아파트 거래월 거래일     전용면적      지번   층  \
# 1746  67.00  2004  2023  도곡동    타워팰리스3   8  18  244.224  467-29  62
# 2092  49.70  2002  2023  도곡동    타워팰리스1  10   9  164.970     467  58
# 1759  39.00  2004  2023  도곡동    타워팰리스3   8  30  141.706  467-29  58
# 1482  99.00  2002  2023  도곡동    타워팰리스1   7  31  301.470     467  55
# 1760  71.80  2003  2023  도곡동    타워팰리스2   8  30  243.140  467-17  53
# ...     ...   ...   ...  ...       ...  ..  ..      ...     ...  ..
# 1447   7.90  1993  2023  수서동      까치마을   7  29   34.440     746   1
# 839    7.30  2005  2023  논현동        학동   5  16   74.600  217-34   1
# 1911   7.21  1993  2023  수서동      까치마을   9   7   39.600     746   1
# 2230   4.60  2003  2023  삼성동     SM드림빌  12  18   52.790   29-11   1
# 698    1.70  2012  2023  역삼동  요진와이시티미니   5   4   12.100   727-9   1
#
#            거래일자          평당금액  경과년수   금액구간
# 1746 2023-08-18   9053.164308    19  5천 이상
# 2092 2023-10-09   9941.807601    21  5천 이상
# ...

# %%
df.sort_values(by = ['층', '거래금액'], ascending = [False, True])
# Out:
#       거래금액  건축년도  거래년도   법정동                아파트 거래월 거래일     전용면적      지번   층  \
# 1746  67.0  2004  2023   도곡동             타워팰리스3   8  18  244.224  467-29  62
# 1759  39.0  2004  2023   도곡동             타워팰리스3   8  30  141.706  467-29  58
# 2092  49.7  2002  2023   도곡동             타워팰리스1  10   9  164.970     467  58
# 1482  99.0  2002  2023   도곡동             타워팰리스1   7  31  301.470     467  55
# 294   35.5  2004  2023   도곡동             타워팰리스3   2  21  141.648  467-29  53
# ...    ...   ...   ...   ...                ...  ..  ..      ...     ...  ..
# 414   41.5  1980  2023  압구정동  현대8차(성수현대:91~95동)   3   4  163.670     481   1
# 575   48.0  2008  2023   삼성동              아델하우스   4  18  211.600    64-5   1
# 841   48.0  2004  2023   논현동              동양파라곤   5  25  180.070     245   1
# 1883  53.7  1980  2023  압구정동  현대8차(성수현대:91~95동)   9  27  163.670     481   1
# 1640  62.5  1983  2023  압구정동             신현대11차   8   3  183.410     433   1
#
#            거래일자          평당금액  경과년수   금액구간
# ...

# %%
df.sort_values(by = '평당금액', ascending = False, ignore_index = True)
# Out:
#        거래금액  건축년도  거래년도   법정동             아파트 거래월 거래일     전용면적      지번   층  \
# 0     37.00  1982  2023   개포동         개포주공4단지   1  27   41.990     189   4
# 1     25.00  1977  2023  압구정동      한양1차(영동한양)  11  10   49.980     490   7
# 2     39.00  1976  2023  압구정동    현대3차(61~64동)  11  23   82.500     443   7
# 3     53.80  1977  2023  압구정동  현대4차저층(51~56동)  10   4  117.910     462   3
# 4     35.00  1977  2023  압구정동      한양1차(영동한양)   9   5   78.050     490   3
# ...     ...   ...   ...   ...             ...  ..  ..      ...     ...  ..
# 2255   3.00  1999  2023   역삼동         현대휴먼터치빌   9  18   35.880  606-18  11
# 2256   5.05  2002  2023   역삼동           역삼동칼라   8   7   60.660  607-17   2
# 2257   3.00  2004  2023   삼성동     LG선릉에클라트(B)   7  21   36.350   142-3  12
# 2258   3.00  2004  2023   삼성동     LG선릉에클라트(B)   3  22   36.470   142-3   9
# 2259   1.90  2012  2023   역삼동           대명벨리온   7  10   23.626   727-2   3
#
#            거래일자          평당금액  경과년수   금액구간
# ...

# %%
df.columns
# Out:
# Index(['거래금액', '건축년도', '거래년도', '법정동', '아파트', '거래월', '거래일', '전용면적', '지번', '층',
#        '거래일자', '평당금액', '경과년수', '금액구간'],
#       dtype='object')

# %%
cols = ['거래금액', '건축년도', '거래년도', '법정동', '아파트', '거래월', '거래일', '전용면적', '지번', '층',
        '거래일자', '평당금액', '경과년수', '금액구간']

# %%
df[sorted(cols)]
# Out:
#        거래금액  거래년도 거래월 거래일       거래일자  건축년도  경과년수   금액구간  법정동       아파트  \
# 0      2.40  2023   1   6 2023-01-06  1999    24  5천 미만  역삼동   현대휴먼터치빌
# 1      2.30  2023   1  12 2023-01-12  2003    20  5천 미만  역삼동     진넥스빌2
# 2     28.00  2023   1  12 2023-01-12  2006    17  5천 이상  역삼동    개나리래미안
# 3      1.40  2023   1  14 2023-01-14  2012    11  5천 미만  역삼동  요진와이시티미니
# 4     21.00  2023   1  19 2023-01-19  2006    17  5천 이상  역삼동    개나리래미안
# ...     ...   ...  ..  ..        ...   ...   ...    ...  ...       ...
# 2255  43.30  2023  12   2 2023-12-02  2002    21  5천 이상  도곡동    타워팰리스1
# 2256  19.20  2023  12   5 2023-12-05  1978    45  5천 이상  도곡동    도곡쌍용예가
# 2257  21.50  2023  12   6 2023-12-06  2006    17  5천 이상  도곡동      도곡렉슬
# 2258   4.18  2023  12  13 2023-12-13  1999    24  5천 미만  도곡동    현대비젼21
# 2259  32.00  2023  12  22 2023-12-22  1985    38  5천 이상  도곡동       우성4
#
#           전용면적      지번   층          평당금액
# 0      25.9200  606-18  10   3055.555556
# ...

# %%
df['거래금액'].count()
# Out:
# 2260

# %%
df['거래금액'].sum()
# Out:
# 48964.308899999996

# %%
df['거래금액'].mean()
# Out:
# 21.665623407079643

# %%
df['거래금액'].std()
# Out:
# 12.117358854020912

# %%
df['거래금액'].min()
# Out:
# 1.4

# %%
df['거래금액'].max()
# Out:
# 99.0

# %%
df.sort_values(by = '거래금액', ascending=False)
# Out:
#        거래금액  건축년도  거래년도   법정동                          아파트 거래월 거래일     전용면적  \
# 1482  99.00  2002  2023   도곡동                       타워팰리스1   7  31  301.470
# 766   90.00  2006  2023   청담동                   상지리츠빌카일룸2차   5  11  244.320
# 362   82.10  2006  2023   청담동                   상지리츠빌카일룸2차   3  18  244.320
# 619   78.00  1976  2023  압구정동  현대1차(12,13,21,22,31,32,33동)   4  27  196.210
# 1733  74.50  2002  2023   도곡동                       타워팰리스1   8   5  244.660
# ...     ...   ...   ...   ...                          ...  ..  ..      ...
# 696    1.70  2012  2023   역삼동                     요진와이시티미니   5   4   12.940
# 698    1.70  2012  2023   역삼동                     요진와이시티미니   5   4   12.100
# 2217   1.70  2012  2023   역삼동                        대명벨리온  12  21   17.684
# 1240   1.65  2012  2023   역삼동                        대명벨리온   7   6   17.684
# 3      1.40  2012  2023   역삼동                     요진와이시티미니   1  14   12.940
#
#           지번   층       거래일자          평당금액  경과년수   금액구간
# ...

# %%
df.groupby(by = '법정동')['거래금액'].count().sort_values(ascending=False)
# Out:
# 법정동
# 개포동     382
# 대치동     371
# 도곡동     312
# 역삼동     256
# 일원동     235
# 수서동     182
# 삼성동     126
# 압구정동    121
# 청담동      89
# 논현동      65
# 자곡동      56
# 세곡동      44
# 신사동      18
# 율현동       3
# Name: 거래금액, dtype: int64

# %%
df.groupby(by = '법정동')['거래금액'].sum().sort_values(ascending=False)
# Out:
# 법정동
# 대치동     9824.0900
# 도곡동     7830.0100
# 개포동     7154.5900
# 압구정동    5355.1500
# 일원동     4433.3400
# 역삼동     4207.7320
# 삼성동     2916.0900
# 청담동     2324.9555
# 수서동     2244.1950
# 논현동      881.2614
# 자곡동      778.3100
# 세곡동      559.9150
# 신사동      422.8700
# 율현동       31.8000
# Name: 거래금액, dtype: float64

# %%
df.groupby(by = '법정동')['거래금액'].mean().sort_values(ascending=False)
# Out:
# 법정동
# 압구정동    44.257438
# 대치동     26.480027
# 청담동     26.123096
# 도곡동     25.096186
# 신사동     23.492778
# 삼성동     23.143571
# 일원동     18.865277
# 개포동     18.729293
# 역삼동     16.436453
# 자곡동     13.898393
# 논현동     13.557868
# 세곡동     12.725341
# 수서동     12.330742
# 율현동     10.600000
# Name: 거래금액, dtype: float64

# %%
df.groupby(by = '법정동')['거래금액'].std().sort_values(ascending=False)
# Out:
# 법정동
# 신사동     20.617350
# 청담동     16.135499
# 삼성동     13.719509
# 도곡동     12.563278
# 압구정동    12.276875
# 대치동      9.682611
# 논현동      9.608798
# 역삼동      9.271425
# 개포동      7.305774
# 일원동      5.718115
# 수서동      4.795038
# 자곡동      2.893454
# 세곡동      1.191815
# 율현동      0.173205
# Name: 거래금액, dtype: float64

# %%
df.groupby(by = '법정동')['거래금액'].min().sort_values(ascending=False)
# Out:
# 법정동
# 압구정동    20.00
# 율현동     10.50
# 세곡동      9.75
# 자곡동      8.98
# 일원동      7.91
# 수서동      7.21
# 신사동      5.50
# 개포동      5.00
# 삼성동      3.00
# 대치동      2.60
# 도곡동      2.59
# 청담동      2.05
# 논현동      1.95
# 역삼동      1.40
# Name: 거래금액, dtype: float64

# %%
df.groupby(by = '법정동')['거래금액'].max().sort_values(ascending=False)
# Out:
# 법정동
# 도곡동     99.00
# 청담동     90.00
# 압구정동    78.00
# 삼성동     65.85
# 신사동     60.50
# 대치동     53.50
# 논현동     48.00
# 개포동     44.80
# 역삼동     43.70
# 일원동     40.00
# 수서동     38.00
# 자곡동     19.50
# 세곡동     15.75
# 율현동     10.80
# Name: 거래금액, dtype: float64

# %%
df['법정동'].unique()
# Out:
# array(['역삼동', '개포동', '청담동', '삼성동', '대치동', '신사동', '압구정동', '일원동', '수서동',
#        '도곡동', '논현동', '세곡동', '자곡동', '율현동'], dtype=object)

# %%
df['법정동'].nunique()
# Out:
# 14

# %%
df.groupby(by = '법정동')['거래금액'].count().sort_values(ascending = False)
# Out:
# 법정동
# 개포동     382
# 대치동     371
# 도곡동     312
# 역삼동     256
# 일원동     235
# 수서동     182
# 삼성동     126
# 압구정동    121
# 청담동      89
# 논현동      65
# 자곡동      56
# 세곡동      44
# 신사동      18
# 율현동       3
# Name: 거래금액, dtype: int64

# %%
df['법정동'].value_counts()
# Out:
# 법정동
# 개포동     382
# 대치동     371
# 도곡동     312
# 역삼동     256
# 일원동     235
# 수서동     182
# 삼성동     126
# 압구정동    121
# 청담동      89
# 논현동      65
# 자곡동      56
# 세곡동      44
# 신사동      18
# 율현동       3
# Name: count, dtype: int64

# %%
df['법정동'].value_counts().sort_index()
# Out:
# 법정동
# 개포동     382
# 논현동      65
# 대치동     371
# 도곡동     312
# 삼성동     126
# 세곡동      44
# 수서동     182
# 신사동      18
# 압구정동    121
# 역삼동     256
# 율현동       3
# 일원동     235
# 자곡동      56
# 청담동      89
# Name: count, dtype: int64

# %%
df['법정동'].value_counts(normalize = True) * 100
# Out:
# 법정동
# 개포동     16.902655
# 대치동     16.415929
# 도곡동     13.805310
# 역삼동     11.327434
# 일원동     10.398230
# 수서동      8.053097
# 삼성동      5.575221
# 압구정동     5.353982
# 청담동      3.938053
# 논현동      2.876106
# 자곡동      2.477876
# 세곡동      1.946903
# 신사동      0.796460
# 율현동      0.132743
# Name: proportion, dtype: float64
